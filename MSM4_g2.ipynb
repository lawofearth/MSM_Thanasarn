# %% [markdown]
# # MSM UTIL

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2
from pandas import DataFrame as df
from numpy import matlib
from scipy.optimize import fminbound, minimize, fsolve
from lmfit import minimize, Minimizer, Parameters, Parameter, report_fit
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from datetime import date
#import winsound
from pylab import rcParams
import pickle
from datetime import date
from time import time
import statsmodels.api as sm
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## T_mat_temp

# %%
def T_mat_temp(kbar):
    """
    Build template for kbar
    :param kbar:
    :return:
    """
#     kbar = int(kbar)
    A = np.fromfunction(lambda i, j: i ^ j, (2**kbar, 2**kbar), dtype=int)
    A_temp = A.astype(float)
    return A_temp

# %% [markdown]
# ## MSM_starting_values(data, startingvals, kbar):

# %%
def MSM_starting_values(data, startingvals, kbar, distribution, dof, send_out):
    """
    find starting values for params
    :param data:
    :param startingvals:
    :param kbar:
    :return:
    """

    # print('No starting values entered: Using grid-search')
    # A grid search used to find the best set of starting values in the
    # event none are supplied by the user
    
    if bool(startingvals):
        dum = startingvals[1]
        b = [1.5, 1.5 + (dum-1.5)/3, 1.5 + 2*(dum-1.5)/3, dum]
        lb = len(b)
        
        dum = startingvals[2]
        g = [dum, (0.99-dum)/2+dum, .99]
        lg = len(g)
        sigma = startingvals[3]
        
    else :
        b = [1.5, 3, 6, 20]
        lb = len(b)
        g = [.1, .5, .99]
        lg = len(g)
        sigma = np.std(data, ddof=1) #* np.sqrt(252)
            
        
    

    LL_storage = df(columns=['LL', 'b', 'g', 'm','sigma'])
    m0_lower = 1.2
    m0_upper = 1.8

    index = 1

    # I know that adding one by one row on DF is quiet inefficient
    # I will try to use lambda, map instead of double for loop if I have a time

    for i in range(0, lb):
        for j in range(0, lg):
            a_m0 = fminbound(MSM_likelihood_new, 1.2, 1.8,
                             args=( b[i], g[j], sigma, kbar, data, distribution, dof, send_out), 
                             xtol=1e-05, maxfun=500, full_output=True)  # , disp=3)
            LL_storage.loc[len(LL_storage), 'LL'] = a_m0[1]
            LL_storage.loc[len(LL_storage) - 1, 'b'] = b[i]
            LL_storage.loc[len(LL_storage) - 1, 'g'] = g[j]
            LL_storage.loc[len(LL_storage) - 1, 'm'] = a_m0[0]

    LL_storage = LL_storage.sort_values(by=['LL'], ascending=True)
    LL_storage = LL_storage.reset_index(drop=True)
#     print(LL_storage)
    startingvals = [0., 0., 0., sigma]
    startingvals[1] = LL_storage.loc[0, 'b']
    startingvals[0] = LL_storage.loc[0, 'm']
    startingvals[2] = LL_storage.loc[0, 'g']

    return startingvals, LL_storage

# %% [markdown]
# ## MSM_likelihood_new(*args):

# %%
def MSM_likelihood_new(*args, distribution = 'Normal', dof = 2, send_out = 'vol'):
    """
    calculate LL for 3 cases (depend on number of input)
    :param args:
    :return:
    """

    if len(args) ==6 :
        # optimize -> minimizer
#         print("len arg =3")
        inp = args[0]
        kbar = args[1]
        data = args[2]
        m0 = inp['m0'].value
        b = inp['b'].value
        gamma_k = inp['gamma_k'].value
        sigma = inp['sigma'].value
        distribution = args[3]
        dof = args[4]
        sendout = args[5]
        

    elif len(args) == 9 :
        # choose starting val -> fminbound
#         print("len arg =9")
        m0 = args[0]
        b = args[1]
        gamma_k = args[2]
        sigma = args[3]
        kbar = args[4]
        data = args[5]
        distribution = args[6]
        dof = args[7]
        sendout = args[8]

    elif len(args) == 4 :
        # for outcome
#         print("len arg =4")
        inp = args[0]
        kbar = args[1]
        data = args[2]
        m0 = inp['m0'].value
        b = inp['b'].value
        gamma_k = inp['gamma_k'].value
        sigma = inp['sigma'].value

    A_temp = T_mat_temp(kbar)
    k2 = 2 ** kbar
#     print("kbar = "+str(kbar))

    def transition_mat(A_temp, b, gamma_k, kbar):
        A = A_temp

        gamma = np.zeros((kbar, 1))
        gamma[0] = 1 - (1 - gamma_k) ** (1 / (b ** (kbar - 1)))

        def bitget(number, position):

            bi_number = bin(number)
            bi_number = bi_number[2:]
            if len(bi_number) >= position:

                fn_output = bi_number[-position]
            else:
                fn_output = 0

            return fn_output

        for i in range(1, kbar):
            gamma[i, 0] = 1 - (1 - gamma[0]) ** (b ** i)

        gamma = gamma / 2
        gamma = np.append(gamma, gamma, axis=1)
        gamma[:, 0] = 1 - gamma[:, 0]
        
         #print(gamma[:,1])
         #print(gamma[-1,1])

        kbar1 = kbar + 1
        kbar2 = 2 ** kbar

        prob = np.ones((kbar2, 1))

        for i in range(0, kbar2):
            for m in range(1, kbar + 1):
                prob[i, 0] = prob[i, 0] * gamma[kbar1 - m - 1, int(bitget(i, m))]

        for i in range(0, 2 ** (kbar - 1)):
            for j in range(i, 2 ** (kbar - 1)):
                A[kbar2 - i - 1, j] = prob[kbar2 - int(A[i, j]) - 1, 0]
                A[kbar2 - j - 1, i] = A[kbar2 - i - 1, j]
                A[j, kbar2 - i - 1] = A[kbar2 - i - 1, j]
                A[i, kbar2 - j - 1] = A[kbar2 - i - 1, j]

                A[i, j] = prob[int(A[i, j]), 0]
                A[j, i] = A[i, j]
                A[kbar2 - i - 1, kbar2 - j - 1] = A[i, j]
                A[kbar2 - j - 1, kbar2 - i - 1] = A[i, j]
        return A, gamma

    def gofm(m0, kbar):

        m1 = 2 - m0
        kbar2 = 2 ** kbar
        g_m1 = list(range(0, kbar2))
        for i in range(0, kbar2):
            g = 1
            for j in range(0, kbar):  # not req -1
                if g_m1[i] & 2 ** j != 0:
                    g = g * m1
                else:
                    g = g * m0
            g_m1[i] = g

        g_m = np.sqrt(g_m1)
        return g_m

    A, gamma = transition_mat(A_temp, b, gamma_k, kbar)
    g_m = gofm(m0, kbar)
    T = len(data)
    pi_mat = np.zeros((T + 1, k2))
    LLs = np.zeros((T,1))
    pi_mat[0, :] = (1 / k2) * np.ones((1, k2))

    # Likelihood Algorithm

    pa = (2 * np.pi) ** (-0.5)

    # g_m is binomial measure ?
    g_m = np.array(g_m).reshape((1, len(g_m)))
    s = np.matlib.repmat(sigma * g_m, T, 1)


    data2 = np.array(data).reshape((len(data), 1))
    
    if distribution == 'Normal':
        w_t = np.matlib.repmat(data2, 1, k2)
        w_t = np.divide(pa * np.e ** (-0.5 * np.power(np.divide(w_t, s), 2)), s)
        w_t = w_t + 10 ** -16
    elif distribution == 'ChiSq':
        w_t = np.matlib.repmat(data2, 1, k2)
        w_t = chi2.pdf(w_t, dof)
        w_t = w_t + 10 ** -16

    for t in range(0, T):
        piA = np.matmul(pi_mat[t, :], A)
        C = np.multiply(w_t[t, :], piA)
        ft = sum(C)

        # stop div by zero if prob are too low
        if ft == 0:
            pi_mat[t + 1, :] = (1 / k2) * np.ones((1, k2))
            print("!!!!!")
        else:
            pi_mat[t + 1, :] = np.divide(C, ft)

        LLs[t] = np.log(np.dot(w_t[t, :], piA))

    LL = -sum(LLs)

    if np.isinf(LL):
        print('Log-likelihood is inf. Probably due to all zeros in pi_mat.')

    if (len(args) == 4) & (send_out == 'vol'):
        # Volatility prediction (single state)
        
        t_predict = args[3]
        vol = np.ones((t_predict,1))
        vol = vol.astype(float)
        state_now = pi_mat[-1 , :]
        
        for t in range(0,t_predict):
            vol[t,0] = sum(np.matmul(state_now, np.linalg.matrix_power(A, t+1)))*sigma
        
        return vol
    
    elif (len(args) == 4) & (send_out == 'forecast multistep'):
        # get state for multiple forecast time 
        
        return pi_mat, A, sigma, s
        
    else:
        return sum(LL)#+1/(2*gamma[-1,1])-1

# %% [markdown]
# ## MSM_fitdata(data, kbar, LB ,UB, op_methods, startingvals):

# %%
def MSM_fitdata(data, kbar, LB ,UB, op_methods, startingvals, distribution , dof , send_out):
    """
    Combine MSM_likelihood_new, MSM_starting_values, T_mat_Temp
    :param data: Must be a column vector of a log return
    from latest day [index0 : 1 Jan 1974] to today [index -1 : 1 Jan 2018]
    multiply it with 100
    :param kbar:
    :param LB:
    :param UB:
    :param op_methods:
    :param startingvals:
    :return:
    """

    input_param, LLS = MSM_starting_values(data, startingvals, kbar, distribution, dof, send_out)
        # print('LL = %8.4f' % LLS.loc[0, 'LL'])
        
     #input_param = startingvals
    
    # create a set of Parameters
    params = Parameters()
    params.add('m0', value=input_param[0], min=LB[0], max=UB[0])
    params.add('b', value=input_param[1], min=LB[1], max=UB[1])
    params.add('gamma_k', input_param[2], min=LB[2], max=UB[2])
    params.add('sigma', value=input_param[3], min=LB[3], max=UB[3])

#     print("==========init params=========")
#     for element in params:
#         print(element + " = %8.4f" % (params[element].value))



    minner = Minimizer(MSM_likelihood_new, params, fcn_args=(kbar, data, distribution , dof , send_out))
    result = minner.minimize(method=op_methods)
    

#     print("\n\n ==========fitted results==========")
#     print('optimization method = ' + op_methods)
#     for element in result.params:
#         print(element + " = %8.4f" % (result.params[element].value))
#     print("\n")
    # print('LLs = %8.4f' % (result.residual))
    # print('AIC = %8.4f' % (result.aic))
    # print('BIC = %8.4f' % (result.bic))

    return result

# %% [markdown]
# ## msm_fitseries(data, kbar, LB, UB, op_methods, startingvals, m, RV):

# %%
def msm_fitseries(data, kbar, LB, UB, op_methods, startingvals, m, RV):
    """
     series of MSM_fitdata for calculate step-by-step
    :param data: 
    :param kbar: 
    :param LB: 
    :param UB: 
    :param op_methods: OPTIMIZATION METHOD
    :param startingvals: 
    :param m: numbers of days we try to estimate
    :param RV: days to calculate RV
    :return: 
    """
    output = df()
    output["RV"] = []
    output["m0"] = []
    output["b"] = []
    output["gamma_k"] = []
    output["sigma"] = []

    for i in range(0, m):
        print("round" + str(i))
        data2 = data[i:len(data) - m + i]
        result = MSM_fitdata(data2, kbar, LB, UB, op_methods, startingvals)
        re2 = MSM_likelihood_new(result.params, kbar, data2, RV)
        output.loc[i, "RV"] = sum(re2) ** 2 * 100
        for element in result.params:
            output.loc[i, element] = result.params[element].value

    return output

# %% [markdown]
# # TEST FIT_PARAMS

# %% [markdown]
# ## INPUT

# %%
filename = 'fed_data.xlsx'
xls = pd.ExcelFile(filename)
CA_raw = pd.read_excel(xls, 'CA')
DM_raw = pd.read_excel(xls, 'DM')
JA_raw = pd.read_excel(xls, 'JA')
UK_raw = pd.read_excel(xls, 'UK')

# %% [markdown]
# ### construct a reaw data matrix

# %%
def T3(dum_data, Table3_Currency_Vol, row):
    returns = 100*np.log(1+dum_data['Column2'].pct_change().dropna())
    subperiod = 4
    Table3_Currency_Vol.loc[row,'Entire'] = float(np.std(returns))
    for i in range(0,subperiod):
        sub_data = dum_data['Column2']
        #print('i = ' + str(i))
        #print('from : ',int(np.floor(i*len(returns)/subperiod)))
        #print('to   : ',int(np.floor((i+1)*len(returns)/subperiod)))
        sub_data = sub_data.iloc[int(np.floor(i*len(returns)/subperiod)):int(np.floor((i+1)*len(returns)/subperiod))]
        returns2 = 100*np.log(1+sub_data.pct_change().dropna())
        Table3_Currency_Vol.iloc[row,i+1] = float(np.std(returns2))
        
    return Table3_Currency_Vol

# %%
Table3_Currency_Vol = df()
Table3_Currency_Vol['Entire']=[]
Table3_Currency_Vol['Sub1']=[]
Table3_Currency_Vol['Sub2']=[]
Table3_Currency_Vol['Sub3']=[]
Table3_Currency_Vol['Sub4']=[]

raw = [DM_raw, JA_raw, UK_raw, CA_raw]
for row in range(0, len(raw)):
    Table3_Currency_Vol = T3(raw[row], Table3_Currency_Vol, row)
Table3_Currency_Vol
# Out:
#      Entire      Sub1      Sub2      Sub3      Sub4
# 0  0.664101  0.586819  0.716642  0.708206  0.635449
# 1  0.656566  0.544619  0.639886  0.645119  0.775137
# 2  0.606847  0.485806  0.724471  0.699407  0.472817
# 3  0.274376  0.220132  0.254553  0.284356  0.326698

# %% [markdown]
# ### plot to see data

# %%
# rcParams['figure.figsize'] = 5, 10

for row in range(0, len(raw)):
    dum_data = raw[row]
    returns = 100*np.log(1+dum_data['Column2'].pct_change().dropna())
    a = returns.to_frame()
    a.plot()

plt.show()

# %% [markdown]
# ## OUTPUT

# %% [markdown]
# #### Construct a output dataframe for store hard working parameters

# %%
output = df()
output["m0"] = []
output["b"] = []
output["gamma_k"]=[]
output["sigma"] = []
output["LL"] = []
result = []

startingvals = []#[1.2, 1.2, 0.5 , 1.2 ]
LB = [1, 1, 0.001, 0.0001]
UB = [1.99, 50, 0.99999, 50]

# %% [markdown]
# ### DM

# %%
op_methods = 'slsqp'
row = 0
dum_data = raw[row]
returns = np.log(1+dum_data['Column2'].pct_change().dropna())
a = returns.to_frame()
data = a['Column2']*100
data2 = data#[::-1]
startingvals = []

for i in range(0,10):
    kbar = i+1
    if kbar >1 and bool(result):
        startingvals = [result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value]
    result = MSM_fitdata(data, kbar, LB ,UB,op_methods, startingvals)
    re2 = MSM_likelihood_new(result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value,  kbar, data2)
    output.loc[i,"LL"] = re2
    for element in result.params:
        output.loc[i,element] = result.params[element].value
        
writer = pd.ExcelWriter('Output'.join((date.today().strftime('%y%m%d'),op_methods+'DMvaryk.xlsx')))
output.to_excel(writer, 'Sheet1')
writer.save()
        
output
# Out:
#          LL    b     g        m sigma
# 0   5924.15  1.5   0.1  1.66418   NaN
# 1   5924.15    3   0.1  1.66418   NaN
# 2   5924.15    6   0.1  1.66418   NaN
# 3   5924.15   20   0.1  1.66418   NaN
# 4   6029.55  1.5   0.5  1.74141   NaN
# 5   6029.55    3   0.5  1.74141   NaN
# 6   6029.55    6   0.5  1.74141   NaN
# 7   6029.55   20   0.5  1.74141   NaN
# 8   6135.42  1.5  0.99  1.73377   NaN
# 9   6135.42    3  0.99  1.73377   NaN
# 10  6135.42    6  0.99  1.73377   NaN
# 11  6135.42   20  0.99  1.73377   NaN
# ==========init params=========
# m0 =   1.6642
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.6642
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.6541
# b =   1.5000
# gamma_k =   0.0747
# sigma =   0.6819
#
#
#          LL    b          g        m sigma
# 0   5794.83  1.5  0.0747172  1.57793   NaN
# 1   5794.83  1.5  0.0747172  1.57793   NaN
# 2   5794.83  1.5  0.0747172  1.57793   NaN
# 3   5794.83  1.5  0.0747172  1.57793   NaN
# 4   5959.69  1.5   0.532359  1.62232   NaN
# 5   5959.69  1.5   0.532359  1.62232   NaN
# 6   5959.69  1.5   0.532359  1.62232   NaN
# 7   5959.69  1.5   0.532359  1.62232   NaN
# 8   6098.13  1.5       0.99  1.60686   NaN
# 9   6098.13  1.5       0.99  1.60686   NaN
# 10  6098.13  1.5       0.99  1.60686   NaN
# 11  6098.13  1.5       0.99  1.60686   NaN
# ==========init params=========
# m0 =   1.5779
# b =   1.5000
# gamma_k =   0.0747
# sigma =   0.6819
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5899
# b =   8.0165
# gamma_k =   0.1068
# sigma =   0.6506
#
#
#          LL        b         g        m sigma
# 0   5742.48   5.8443  0.106826  1.53916   NaN
# 1   5743.16  8.01646  0.106826  1.54353   NaN
# 2   5745.42  3.67215  0.106826  1.52949   NaN
# 3   5748.58  8.01646  0.548413  1.54262   NaN
# 4   5761.88   5.8443  0.548413  1.53308   NaN
# 5   5768.66      1.5  0.106826  1.50806   NaN
# 6   5797.98  3.67215  0.548413   1.5234   NaN
# 7   5832.22  8.01646      0.99  1.53146   NaN
# 8   5876.75   5.8443      0.99  1.52915   NaN
# 9   5925.43      1.5  0.548413  1.51918   NaN
# 10  5963.16  3.67215      0.99   1.5232   NaN
# 11  6084.62      1.5      0.99   1.4986   NaN
# ==========init params=========
# m0 =   1.5392
# b =   5.8443
# gamma_k =   0.1068
# sigma =   0.6506
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5546
# b =  21.9143
# gamma_k =   0.6725
# sigma =   0.6003
#
#
#          LL        b         g        m sigma
# 0   5717.63  8.30478  0.672529   1.4891   NaN
# 1   5718.18  15.1096  0.831264  1.49986   NaN
# 2    5721.7  8.30478  0.831264  1.48425   NaN
# 3   5722.63  15.1096  0.672529  1.50411   NaN
# 4   5725.01  21.9143  0.831264  1.51143   NaN
# 5   5726.66  21.9143      0.99   1.4986   NaN
# 6   5726.94  15.1096      0.99  1.48759   NaN
# 7   5732.49  21.9143  0.672529  1.52361   NaN
# 8   5743.15  8.30478      0.99  1.48111   NaN
# 9   5947.22      1.5  0.672529  1.44344   NaN
# 10  6006.26      1.5  0.831264  1.43817   NaN
# 11  6097.01      1.5      0.99   1.4184   NaN
# ==========init params=========
# m0 =   1.4891
# b =   8.3048
# gamma_k =   0.6725
# sigma =   0.6003
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4915
# b =  10.4203
# gamma_k =   0.7135
# sigma =   0.5716
#
#
#          LL        b         g        m sigma
# 0   5711.67  7.44686  0.713536  1.46605   NaN
# 1   5713.05  7.44686  0.851768  1.45903   NaN
# 2    5713.3  10.4203  0.851768  1.47689   NaN
# 3   5714.25  10.4203  0.713536  1.47954   NaN
# 4   5716.69  4.47343  0.713536  1.43083   NaN
# 5      5717  7.44686      0.99  1.44136   NaN
# 6    5718.4  10.4203      0.99  1.46041   NaN
# 7    5721.7  4.47343  0.851768  1.42902   NaN
# 8   5748.84  4.47343      0.99  1.42588   NaN
# 9   5945.11      1.5  0.713536  1.39672   NaN
# 10  6004.85      1.5  0.851768  1.39217   NaN
# 11     6110      1.5      0.99  1.37371   NaN
# ==========init params=========
# m0 =   1.4660
# b =   7.4469
# gamma_k =   0.7135
# sigma =   0.5716
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4619
# b =   7.8867
# gamma_k =   0.7506
# sigma =   0.5117
#
#
#          LL        b         g        m sigma
# 0   5708.24  5.75778  0.870317  1.41686   NaN
# 1   5710.19  5.75778      0.99  1.41541   NaN
# 2   5710.51  5.75778  0.750633  1.41764   NaN
# 3   5711.05  7.88667      0.99  1.42246   NaN
# 4    5714.5  3.62889  0.750633  1.40295   NaN
# 5   5716.52  7.88667  0.870317  1.42748   NaN
# 6   5716.94  7.88667  0.750633  1.46487   NaN
# 7   5721.03  3.62889  0.870317  1.40125   NaN
# 8   5749.43  3.62889      0.99  1.39694   NaN
# 9   5997.34      1.5  0.750633  1.36755   NaN
# 10  6069.34      1.5  0.870317  1.36277   NaN
# 11  6212.19      1.5      0.99  1.34459   NaN
# ==========init params=========
# m0 =   1.4169
# b =   5.7578
# gamma_k =   0.8703
# sigma =   0.5117
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4129
# b =   5.1603
# gamma_k =   0.8583
# sigma =   0.5377
#
#
#          LL        b         g        m sigma
# 0   5704.71  3.94019  0.924136  1.37757   NaN
# 1   5705.02  3.94019  0.858273  1.38006   NaN
# 2   5706.25  5.16029      0.99  1.38429   NaN
# 3   5709.09  3.94019      0.99  1.37485   NaN
# 4    5709.6  5.16029  0.924136  1.39366   NaN
# 5   5712.42  5.16029  0.858273  1.40555   NaN
# 6   5720.89   2.7201  0.858273  1.36041   NaN
# 7   5727.88   2.7201  0.924136  1.35941   NaN
# 8   5751.34   2.7201      0.99   1.3585   NaN
# 9    5960.3      1.5  0.858273  1.33878   NaN
# 10  6005.53      1.5  0.924136  1.33597   NaN
# 11   6098.2      1.5      0.99  1.32571   NaN
# ==========init params=========
# m0 =   1.3776
# b =   3.9402
# gamma_k =   0.9241
# sigma =   0.5377
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.3798
# b =   4.1176
# gamma_k =   0.9315
# sigma =   0.5467
#
#
#          LL        b         g        m sigma
# 0   5704.87  3.24509  0.960766  1.35102   NaN
# 1   5705.05  3.24509  0.931533  1.35276   NaN
# 2   5706.51  3.24509      0.99  1.34866   NaN
# 3   5707.94  4.11763      0.99  1.36395   NaN
# 4   5710.14  4.11763  0.960766  1.37167   NaN
# 5   5710.81  4.11763  0.931533  1.38613   NaN
# 6   5724.83  2.37254  0.931533  1.33386   NaN
# 7   5730.61  2.37254  0.960766  1.33343   NaN
# 8   5744.89  2.37254      0.99  1.33309   NaN
# 9    5948.8      1.5  0.931533  1.31801   NaN
# 10  5978.24      1.5  0.960766  1.31627   NaN
# 11  6033.54      1.5      0.99  1.31135   NaN
# ==========init params=========
# m0 =   1.3510
# b =   3.2451
# gamma_k =   0.9608
# sigma =   0.5467
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.3527
# b =   3.3817
# gamma_k =   0.9737
# sigma =   0.5504
#
#
#          LL        b         g        m sigma
# 0   5705.66   2.7545  0.973716  1.32777   NaN
# 1   5705.99   2.7545  0.981858  1.32708   NaN
# 2   5706.77   2.7545      0.99  1.32622   NaN
# 3   5707.76  3.38175      0.99  1.34129   NaN
# 4    5708.1  3.38175  0.981858  1.34406   NaN
# 5   5708.28  3.38175  0.973716  1.34666   NaN
# 6    5733.1  2.12725  0.973716  1.31275   NaN
# 7   5736.89  2.12725  0.981858  1.31267   NaN
# 8   5742.95  2.12725      0.99  1.31262   NaN
# 9   5942.38      1.5  0.973716    1.301   NaN
# 10  5957.16      1.5  0.981858  1.30018   NaN
# 11  5978.51      1.5      0.99  1.29873   NaN
# ==========init params=========
# m0 =   1.3278
# b =   2.7545
# gamma_k =   0.9737
# sigma =   0.5504
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.3306
# b =   2.8501
# gamma_k =   0.9729
# sigma =   0.5601
#
#
#          LL        b         g        m sigma
# 0   5706.02  2.40006  0.972934  1.30857   NaN
# 1   5706.13   2.8501      0.99   1.3213   NaN
# 2   5706.21   2.8501  0.981467  1.32392   NaN
# 3   5706.29   2.8501  0.972934   1.3261   NaN
# 4    5706.5  2.40006  0.981467  1.30782   NaN
# 5    5707.5  2.40006      0.99  1.30685   NaN
# 6   5731.06  1.95003  0.972934  1.29543   NaN
# 7   5734.75  1.95003  0.981467  1.29537   NaN
# 8   5740.77  1.95003      0.99  1.29536   NaN
# 9   5885.41      1.5  0.972934  1.28852   NaN
# 10  5898.92      1.5  0.981467  1.28821   NaN
# 11  5919.08      1.5      0.99  1.28748   NaN
# ==========init params=========
# m0 =   1.3086
# b =   2.4001
# gamma_k =   0.9729
# sigma =   0.5601
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.3257
# b =   2.7025
# gamma_k =   0.9589
# sigma =   0.6432
#          m0          b   gamma_k     sigma           LL
# 0  1.654133   1.500000  0.074717  0.681917  5920.855214
# 1  1.589895   8.016456  0.106826  0.650560  5782.955933
# 2  1.554623  21.914346  0.672529  0.600255  5731.776138
# 3  1.491546  10.420285  0.713536  0.571605  5715.300200
# 4  1.461936   7.886674  0.750633  0.511672  5708.240226
# 5  1.412923   5.160288  0.858273  0.537734  5706.903687
# 6  1.379843   4.117634  0.931533  0.546732  5704.470829
# 7  1.352666   3.381746  0.973716  0.550389  5704.765369
# 8  1.330602   2.850096  0.972934  0.560066  5705.342737
# 9  1.325676   2.702472  0.958863  0.643250  5705.085364

# %% [markdown]
# ### JPY

# %%
op_methods = 'slsqp'
row = 1
dum_data = raw[row]
returns = np.log(1+dum_data['Column2'].pct_change().dropna())
a = returns.to_frame()
data = a['Column2']*100
data2 = data#[::-1]
startingvals = []

for i in range(0,10):
    kbar = i+1
    if kbar >1 and bool(result):
        startingvals = [result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value]
    result = MSM_fitdata(data, kbar, LB ,UB,op_methods, startingvals)
    re2 = MSM_likelihood_new(result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value,  kbar, data2)
    output.loc[i,"LL"] = re2
    for element in result.params:
        output.loc[i,element] = result.params[element].value
        
writer = pd.ExcelWriter('Output'.join((date.today().strftime('%y%m%d'),op_methods+'JPYvaryk.xlsx')))
output.to_excel(writer, 'Sheet1')
writer.save()
        
output
# Out:
#          LL    b     g        m sigma
# 0   6474.43  1.5   0.1  1.75145   NaN
# 1   6474.43    3   0.1  1.75145   NaN
# 2   6474.43    6   0.1  1.75145   NaN
# 3   6474.43   20   0.1  1.75145   NaN
# 4   6506.28  1.5   0.5  1.79999   NaN
# 5   6506.28    3   0.5  1.79999   NaN
# 6   6506.28    6   0.5  1.79999   NaN
# 7   6506.28   20   0.5  1.79999   NaN
# 8   6657.16  1.5  0.99  1.79999   NaN
# 9   6657.16    3  0.99  1.79999   NaN
# 10  6657.16    6  0.99  1.79999   NaN
# 11  6657.16   20  0.99  1.79999   NaN
# ==========init params=========
# m0 =   1.7514
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.6566
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.7969
# b =   1.5000
# gamma_k =   0.1989
# sigma =   0.6298
#
#
#          LL    b         g        m sigma
# 0   6198.81  1.5  0.198939  1.71102   NaN
# 1   6198.81  1.5  0.198939  1.71102   NaN
# 2   6198.81  1.5  0.198939  1.71102   NaN
# 3   6198.81  1.5  0.198939  1.71102   NaN
# 4   6368.15  1.5  0.594469  1.71573   NaN
# 5   6368.15  1.5  0.594469  1.71573   NaN
# 6   6368.15  1.5  0.594469  1.71573   NaN
# 7   6368.15  1.5  0.594469  1.71573   NaN
# 8    6568.8  1.5      0.99  1.67682   NaN
# 9    6568.8  1.5      0.99  1.67682   NaN
# 10   6568.8  1.5      0.99  1.67682   NaN
# 11   6568.8  1.5      0.99  1.67682   NaN
# ==========init params=========
# m0 =   1.7110
# b =   1.5000
# gamma_k =   0.1989
# sigma =   0.6298
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.7761
# b =  50.0000
# gamma_k =   0.3261
# sigma =   0.5430
#
#
#          LL        b         g        m sigma
# 0   5963.09  17.6667  0.326086  1.68829   NaN
# 1   5968.21  17.6667  0.658043  1.68934   NaN
# 2   5972.59  33.8333  0.658043  1.68323   NaN
# 3   5978.96  33.8333  0.326086  1.68916   NaN
# 4   5980.24       50      0.99  1.69085   NaN
# 5   5983.79       50  0.658043  1.68021   NaN
# 6   5991.43  33.8333      0.99  1.69535   NaN
# 7   5992.22       50  0.326086  1.69033   NaN
# 8   6043.31  17.6667      0.99  1.69295   NaN
# 9   6188.09      1.5  0.326086   1.6467   NaN
# 10  6394.62      1.5  0.658043  1.60796   NaN
# 11  6645.14      1.5      0.99  1.54692   NaN
# ==========init params=========
# m0 =   1.6883
# b =  17.6667
# gamma_k =   0.3261
# sigma =   0.5430
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.6930
# b =  12.4571
# gamma_k =   0.3119
# sigma =   0.5656
#
#
#          LL        b         g        m sigma
# 0   5913.76  12.4571  0.650972  1.65684   NaN
# 1   5915.08  8.80472  0.650972  1.64714   NaN
# 2   5930.03  8.80472  0.311943  1.67402   NaN
# 3   5934.15  5.15236  0.311943  1.64253   NaN
# 4   5934.39  12.4571  0.311943  1.68262   NaN
# 5   5939.31  12.4571      0.99  1.62725   NaN
# 6   5945.58  5.15236  0.650972   1.6286   NaN
# 7   5967.45  8.80472      0.99   1.6233   NaN
# 8   6069.35  5.15236      0.99  1.60041   NaN
# 9   6108.83      1.5  0.311943   1.5797   NaN
# 10  6294.61      1.5  0.650972  1.55083   NaN
# 11  6565.61      1.5      0.99  1.49463   NaN
# ==========init params=========
# m0 =   1.6568
# b =  12.4571
# gamma_k =   0.6510
# sigma =   0.5656
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.6540
# b =  15.5850
# gamma_k =   0.6974
# sigma =   0.4619
#
#
#          LL        b         g        m sigma
# 0   5887.43    10.89  0.843691  1.58338   NaN
# 1   5887.51  6.19499  0.697383  1.58433   NaN
# 2   5888.21    10.89      0.99  1.58664   NaN
# 3   5890.91   15.585      0.99  1.58289   NaN
# 4   5891.33  6.19499  0.843691  1.58298   NaN
# 5    5896.1    10.89  0.697383  1.58322   NaN
# 6   5900.91   15.585  0.843691   1.5816   NaN
# 7   5912.12   15.585  0.697383  1.65069   NaN
# 8    5927.6  6.19499      0.99  1.57129   NaN
# 9   6413.38      1.5  0.697383   1.5025   NaN
# 10  6560.29      1.5  0.843691  1.48433   NaN
# 11  6828.66      1.5      0.99   1.4424   NaN
# ==========init params=========
# m0 =   1.5834
# b =  10.8900
# gamma_k =   0.8437
# sigma =   0.4619
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5863
# b =   8.7179
# gamma_k =   0.8692
# sigma =   0.4641
#
#
#          LL        b         g        m sigma
# 0   5875.94  6.31196  0.929625  1.53569   NaN
# 1   5877.75  6.31196      0.99  1.53035   NaN
# 2   5878.54  6.31196   0.86925  1.54013   NaN
# 3   5880.01  8.71794      0.99  1.53818   NaN
# 4   5886.38  8.71794   0.86925  1.58818   NaN
# 5   5886.63  8.71794  0.929625  1.56091   NaN
# 6   5894.55  3.90598   0.86925  1.52494   NaN
# 7   5904.16  3.90598  0.929625  1.52328   NaN
# 8   5935.58  3.90598      0.99  1.51845   NaN
# 9   6484.99      1.5   0.86925  1.45035   NaN
# 10  6573.27      1.5  0.929625  1.43927   NaN
# 11  6740.68      1.5      0.99  1.41508   NaN
# ==========init params=========
# m0 =   1.5357
# b =   6.3120
# gamma_k =   0.9296
# sigma =   0.4641
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5341
# b =   6.2966
# gamma_k =   0.9565
# sigma =   0.4670
#
#
#          LL        b         g        m sigma
# 0    5872.6  6.29655   0.95645   1.5453   NaN
# 1    5873.7  6.29655  0.973225  1.54077   NaN
# 2   5873.93   4.6977  0.973225  1.50085   NaN
# 3   5874.05   4.6977   0.95645  1.50538   NaN
# 4   5874.18   4.6977      0.99  1.49586   NaN
# 5   5875.22  6.29655      0.99  1.52884   NaN
# 6   5906.01  3.09885   0.95645  1.48246   NaN
# 7   5913.38  3.09885  0.973225  1.48125   NaN
# 8   5928.41  3.09885      0.99  1.47914   NaN
# 9   6519.65      1.5   0.95645  1.41201   NaN
# 10   6566.2      1.5  0.973225  1.40625   NaN
# 11  6640.78      1.5      0.99  1.39638   NaN
# ==========init params=========
# m0 =   1.5453
# b =   6.2966
# gamma_k =   0.9565
# sigma =   0.4670
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5276
# b =   6.0069
# gamma_k =   0.9661
# sigma =   0.3914
#
#
#          LL        b         g        m sigma
# 0   5869.21  4.50457      0.99  1.48696   NaN
# 1   5869.62  4.50457  0.978044  1.48992   NaN
# 2   5870.31  4.50457  0.966087  1.49193   NaN
# 3   5875.54  6.00685  0.966087  1.53599   NaN
# 4   5876.12  6.00685      0.99  1.50863   NaN
# 5   5876.24  6.00685  0.978044  1.52641   NaN
# 6   5895.72  3.00228  0.966087  1.46034   NaN
# 7   5900.77  3.00228  0.978044  1.45913   NaN
# 8   5910.31  3.00228      0.99  1.45769   NaN
# 9   6728.08      1.5  0.966087   1.4104   NaN
# 10   6788.9      1.5  0.978044  1.40619   NaN
# 11  6883.47      1.5      0.99  1.39922   NaN
# ==========init params=========
# m0 =   1.4870
# b =   4.5046
# gamma_k =   0.9900
# sigma =   0.3914
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5128
# b =   5.6497
# gamma_k =   0.9748
# sigma =   0.5139
#
#
#          LL        b         g        m sigma
# 0   5863.71  4.26644      0.99  1.47697   NaN
# 1   5864.37  4.26644  0.982399  1.47919   NaN
# 2   5865.08  4.26644  0.974797  1.48071   NaN
# 3   5872.13  2.88322  0.974797  1.44084   NaN
# 4   5872.17  5.64965  0.974797  1.52514   NaN
# 5   5872.21  5.64965      0.99   1.5083   NaN
# 6   5872.34  5.64965  0.982399  1.51991   NaN
# 7   5873.37  2.88322  0.982399  1.43947   NaN
# 8   5875.42  2.88322      0.99  1.43765   NaN
# 9   6289.57      1.5  0.974797  1.37885   NaN
# 10  6313.21      1.5  0.982399  1.37624   NaN
# 11   6346.9      1.5      0.99  1.37234   NaN
# ==========init params=========
# m0 =   1.4770
# b =   4.2664
# gamma_k =   0.9900
# sigma =   0.5139
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4752
# b =   4.4308
# gamma_k =   0.9954
# sigma =   0.4863
#
#
#          LL        b        g        m sigma
# 0   5863.16   3.4539  0.99542  1.44254   NaN
# 1   5863.19   3.4539  0.99271  1.44505   NaN
# 2   5863.29   3.4539     0.99  1.44674   NaN
# 3      5867  4.43084  0.99542  1.47488   NaN
# 4   5867.48  4.43084  0.99271  1.47817   NaN
# 5   5867.85  4.43084     0.99  1.48054   NaN
# 6   5876.67  2.47695     0.99  1.41046   NaN
# 7   5877.99  2.47695  0.99271  1.40968   NaN
# 8   5880.01  2.47695  0.99542  1.40868   NaN
# 9   6307.63      1.5     0.99  1.36159   NaN
# 10  6326.15      1.5  0.99271  1.35984   NaN
# 11  6351.67      1.5  0.99542  1.35736   NaN
# ==========init params=========
# m0 =   1.4425
# b =   3.4539
# gamma_k =   0.9954
# sigma =   0.4863
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4481
# b =   3.7617
# gamma_k =   0.9976
# sigma =   0.4610
#          m0          b   gamma_k     sigma           LL
# 0  1.796889   1.500000  0.198939  0.629831  6451.792036
# 1  1.776111  50.000000  0.326086  0.542971  6106.053752
# 2  1.693020  12.457074  0.311943  0.565602  5959.710137
# 3  1.654031  15.584963  0.697383  0.461888  5900.663844
# 4  1.586325   8.717936  0.869250  0.464081  5883.238714
# 5  1.534078   6.296554  0.956450  0.466958  5875.473759
# 6  1.527624   6.006854  0.966087  0.391437  5870.013921
# 7  1.512750   5.649653  0.974797  0.513890  5863.189012
# 8  1.475161   4.430843  0.995420  0.486330  5862.997348
# 9  1.448112   3.761698  0.997645  0.461049  5862.674907

# %% [markdown]
# ### GBP

# %%
kbar >1 and bool([])
# Out:
# False

# %%
op_methods = 'slsqp'
row = 2
dum_data = raw[row]
returns = np.log(1+dum_data['Column2'].pct_change().dropna())
a = returns.to_frame()
data = a['Column2']*100
data2 = data#[::-1]
startingvals = []


for i in range(0,10):
    kbar = i+1
    print(kbar)
    
    if kbar >1 and bool(result):
        startingvals = [result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value]
    
    result = MSM_fitdata(data, kbar, LB ,UB,op_methods, startingvals)
    re2 = MSM_likelihood_new(result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value,  kbar, data2)
    output.loc[i,"LL"] = re2
    for element in result.params:
        output.loc[i,element] = result.params[element].value
        
writer = pd.ExcelWriter('Output'.join((date.today().strftime('%y%m%d'),op_methods+'GBPvaryk5.xlsx')))
output.to_excel(writer, 'Sheet1')
writer.save()
        
output
# Out:
# 1
#          LL    b     g        m sigma
# 0   5960.39  1.5   0.1  1.71092   NaN
# 1   5960.39    3   0.1  1.71092   NaN
# 2   5960.39    6   0.1  1.71092   NaN
# 3   5960.39   20   0.1  1.71092   NaN
# 4   6042.08  1.5   0.5  1.79291   NaN
# 5   6042.08    3   0.5  1.79291   NaN
# 6   6042.08    6   0.5  1.79291   NaN
# 7   6042.08   20   0.5  1.79291   NaN
# 8   6195.76  1.5  0.99  1.78486   NaN
# 9   6195.76    3  0.99  1.78486   NaN
# 10  6195.76    6  0.99  1.78486   NaN
# 11  6195.76   20  0.99  1.78486   NaN
# ==========init params=========
# m0 =   1.7109
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.6069
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.7157
# b =   1.5000
# gamma_k =   0.1099
# sigma =   0.6087
#
#
# 2
#          LL    b         g        m sigma
# 0   5766.16  1.5  0.109946  1.65469   NaN
# 1   5766.16  1.5  0.109946  1.65469   NaN
# 2   5766.16  1.5  0.109946  1.65469   NaN
# 3   5766.16  1.5  0.109946  1.65469   NaN
# 4   5938.49  1.5  0.549973  1.67616   NaN
# 5   5938.49  1.5  0.549973  1.67616   NaN
# 6   5938.49  1.5  0.549973  1.67616   NaN
# 7   5938.49  1.5  0.549973  1.67616   NaN
# 8   6134.94  1.5      0.99  1.64867   NaN
# 9   6134.94  1.5      0.99  1.64867   NaN
# 10  6134.94  1.5      0.99  1.64867   NaN
# 11  6134.94  1.5      0.99  1.64867   NaN
# ==========init params=========
# m0 =   1.6547
# b =   1.5000
# gamma_k =   0.1099
# sigma =   0.6087
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.6715
# b =  19.9051
# gamma_k =   0.2222
# sigma =   0.5895
#
#
# 3
#          LL        b         g        m sigma
# 0   5630.78  13.7701  0.222162  1.66541   NaN
# 1   5633.36  19.9051  0.222162  1.66549   NaN
# 2   5636.12  7.63504  0.222162  1.65588   NaN
# 3    5638.8  19.9051  0.606081   1.6524   NaN
# 4   5639.54  13.7701  0.606081  1.63683   NaN
# 5   5656.63  7.63504  0.606081  1.61859   NaN
# 6    5677.7  19.9051      0.99  1.61706   NaN
# 7   5702.61  13.7701      0.99  1.60989   NaN
# 8   5737.05      1.5  0.222162  1.58817   NaN
# 9   5775.23  7.63504      0.99  1.59757   NaN
# 10  5902.99      1.5  0.606081  1.58337   NaN
# 11  6114.47      1.5      0.99  1.54873   NaN
# ==========init params=========
# m0 =   1.6654
# b =  13.7701
# gamma_k =   0.2222
# sigma =   0.5895
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.6477
# b =  14.2864
# gamma_k =   0.2780
# sigma =   0.5134
#
#
# 4
#          LL        b         g        m sigma
# 0   5571.69  14.2864  0.633994  1.61285   NaN
# 1   5574.49  10.0242  0.633994  1.60209   NaN
# 2    5577.3  10.0242  0.277987  1.62001   NaN
# 3   5578.67  14.2864  0.277987  1.62785   NaN
# 4   5583.52  5.76212  0.277987  1.60019   NaN
# 5   5601.04  5.76212  0.633994  1.58413   NaN
# 6   5607.99  14.2864      0.99  1.59254   NaN
# 7   5628.64  10.0242      0.99  1.57317   NaN
# 8   5695.81  5.76212      0.99  1.53893   NaN
# 9   5738.93      1.5  0.277987  1.51839   NaN
# 10  5914.06      1.5  0.633994  1.49909   NaN
# 11  6174.57      1.5      0.99  1.45411   NaN
# ==========init params=========
# m0 =   1.6129
# b =  14.2864
# gamma_k =   0.6340
# sigma =   0.5134
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.6092
# b =  12.5064
# gamma_k =   0.6449
# sigma =   0.4672
#
#
# 5
#          LL        b        g        m sigma
# 0   5540.09  12.5064  0.64494  1.58371   NaN
# 1   5544.82  8.83763  0.64494  1.57566   NaN
# 2   5546.65  12.5064  0.81747  1.57782   NaN
# 3   5554.31  8.83763  0.81747  1.56025   NaN
# 4   5566.59  5.16881  0.64494  1.54307   NaN
# 5   5569.52  12.5064     0.99  1.55122   NaN
# 6   5577.99  8.83763     0.99  1.53523   NaN
# 7   5579.71  5.16881  0.81747  1.52819   NaN
# 8   5628.19  5.16881     0.99  1.51391   NaN
# 9    5928.7      1.5  0.64494  1.45492   NaN
# 10  6047.57      1.5  0.81747  1.44275   NaN
# 11  6266.79      1.5     0.99  1.40913   NaN
# ==========init params=========
# m0 =   1.5837
# b =  12.5064
# gamma_k =   0.6449
# sigma =   0.4672
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5789
# b =  11.0175
# gamma_k =   0.6371
# sigma =   0.4213
#
#
# 6
#          LL        b         g        m sigma
# 0   5527.13  7.84502  0.637128  1.53234   NaN
# 1   5527.81  7.84502  0.813564  1.52511   NaN
# 2   5528.04  11.0175  0.813564  1.53878   NaN
# 3   5530.85  11.0175  0.637128  1.54535   NaN
# 4   5535.15  11.0175      0.99   1.5227   NaN
# 5   5537.59  4.67251  0.637128  1.50893   NaN
# 6   5540.36  7.84502      0.99  1.51501   NaN
# 7   5545.94  4.67251  0.813564  1.50567   NaN
# 8   5587.49  4.67251      0.99  1.49075   NaN
# 9   5948.32      1.5  0.637128  1.43288   NaN
# 10  6098.58      1.5  0.813564  1.42169   NaN
# 11  6414.45      1.5      0.99  1.38807   NaN
# ==========init params=========
# m0 =   1.5323
# b =   7.8450
# gamma_k =   0.6371
# sigma =   0.4213
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5337
# b =   8.3156
# gamma_k =   0.7835
# sigma =   0.4676
#
#
# 7
#          LL        b         g        m sigma
# 0   5524.03  6.04375  0.886737  1.49789   NaN
# 1   5524.54  6.04375  0.783474  1.50532   NaN
# 2   5527.18  6.04375      0.99  1.48397   NaN
# 3   5527.55  8.31563      0.99  1.50077   NaN
# 4    5528.7  8.31563  0.783474  1.53149   NaN
# 5   5528.84  8.31563  0.886737   1.5185   NaN
# 6   5534.69  3.77188  0.783474  1.47308   NaN
# 7   5540.67  3.77188  0.886737  1.46664   NaN
# 8   5563.69  3.77188      0.99  1.45256   NaN
# 9   5881.31      1.5  0.783474  1.39092   NaN
# 10  5962.68      1.5  0.886737  1.38435   NaN
# 11  6143.87      1.5      0.99  1.36424   NaN
# ==========init params=========
# m0 =   1.4979
# b =   6.0438
# gamma_k =   0.8867
# sigma =   0.4676
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5033
# b =   6.7155
# gamma_k =   0.8113
# sigma =   0.3891
#
#
# 8
#          LL        b         g        m sigma
# 0   5515.99  4.97698  0.900661  1.46103   NaN
# 1   5518.03  6.71548      0.99  1.46649   NaN
# 2    5518.1  4.97698      0.99  1.45477   NaN
# 3    5518.6  4.97698  0.811321  1.46415   NaN
# 4   5525.19  6.71548  0.900661  1.47856   NaN
# 5   5527.66  6.71548  0.811321  1.50637   NaN
# 6   5528.64  3.23849  0.811321  1.44138   NaN
# 7   5535.31  3.23849  0.900661  1.43889   NaN
# 8   5561.11  3.23849      0.99  1.43262   NaN
# 9    6004.8      1.5  0.811321   1.3883   NaN
# 10   6119.3      1.5  0.900661  1.38237   NaN
# 11  6392.52      1.5      0.99  1.36384   NaN
# ==========init params=========
# m0 =   1.4610
# b =   4.9770
# gamma_k =   0.9007
# sigma =   0.3891
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4605
# b =   5.2325
# gamma_k =   0.9584
# sigma =   0.3838
#
#
# 9
#          LL        b         g        m sigma
# 0   5515.38  3.98835  0.958404  1.42731   NaN
# 1   5515.52  3.98835  0.974202  1.42603   NaN
# 2   5516.62  3.98835      0.99  1.42426   NaN
# 3   5519.72  5.23253      0.99  1.43764   NaN
# 4   5521.11  5.23253  0.974202  1.44299   NaN
# 5   5522.06  5.23253  0.958404  1.45096   NaN
# 6    5544.2  2.74418  0.958404  1.40838   NaN
# 7   5549.79  2.74418  0.974202  1.40748   NaN
# 8   5560.64  2.74418      0.99  1.40594   NaN
# 9   6145.63      1.5  0.958404  1.36244   NaN
# 10  6200.84      1.5  0.974202  1.35936   NaN
# 11  6294.85      1.5      0.99  1.35362   NaN
# ==========init params=========
# m0 =   1.4273
# b =   3.9884
# gamma_k =   0.9584
# sigma =   0.3838
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4282
# b =   4.0752
# gamma_k =   0.9644
# sigma =   0.3736
#
#
# 10
#          LL        b         g        m sigma
# 0   5515.31  3.21683  0.964411  1.40086   NaN
# 1   5515.67  3.21683  0.977206  1.39973   NaN
# 2   5516.99  3.21683      0.99   1.3981   NaN
# 3   5517.95  4.07524      0.99    1.413   NaN
# 4   5518.76  4.07524  0.977206  1.41918   NaN
# 5   5519.07  4.07524  0.964411  1.42728   NaN
# 6   5554.17  2.35841  0.964411  1.38352   NaN
# 7   5560.51  2.35841  0.977206  1.38298   NaN
# 8   5572.05  2.35841      0.99  1.38218   NaN
# 9   6084.47      1.5  0.964411  1.35257   NaN
# 10  6133.24      1.5  0.977206  1.35044   NaN
# 11  6213.88      1.5      0.99  1.34657   NaN
# ==========init params=========
# m0 =   1.4009
# b =   3.2168
# gamma_k =   0.9644
# sigma =   0.3736
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4030
# b =   3.4507
# gamma_k =   0.9818
# sigma =   0.3704
#          m0          b   gamma_k     sigma           LL
# 0  1.715749   1.500000  0.109946  0.608671  5960.169424
# 1  1.671453  19.905125  0.222162  0.589502  5724.358738
# 2  1.647739  14.286373  0.277987  0.513368  5622.725978
# 3  1.609153  12.506440  0.644940  0.467186  5570.014433
# 4  1.578921  11.017527  0.637128  0.421256  5537.792457
# 5  1.533702   8.315625  0.783474  0.467635  5523.628778
# 6  1.503309   6.715476  0.811321  0.389147  5516.877211
# 7  1.460527   5.232527  0.958404  0.383777  5515.366208
# 8  1.428160   4.075240  0.964411  0.373594  5515.268775
# 9  1.402960   3.450710  0.981753  0.370389  5514.933868

# %% [markdown]
# ### CAD

# %%
op_methods = 'slsqp'
row = 3
dum_data = raw[row]
returns = np.log(1+dum_data['Column2'].pct_change().dropna())
a = returns.to_frame()
data = a['Column2']*100
data2 = data#[::-1]
startingvals = []

for i in range(0,10):
    kbar = i+1
    if kbar >1 and bool(result):
        startingvals = [result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value]
    result = MSM_fitdata(data, kbar, LB ,UB,op_methods, startingvals)
    re2 = MSM_likelihood_new(result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value,  kbar, data2)
    output.loc[i,"LL"] = re2
    for element in result.params:
        output.loc[i,element] = result.params[element].value

writer = pd.ExcelWriter('Output'.join((date.today().strftime('%y%m%d'),op_methods+'CADvaryk.xlsx')))
output.to_excel(writer, 'Sheet1')
writer.save()

output
# Out:
#          LL    b     g        m sigma
# 0   277.435  1.5   0.1  1.66057   NaN
# 1   277.435    3   0.1  1.66057   NaN
# 2   277.435    6   0.1  1.66057   NaN
# 3   277.435   20   0.1  1.66057   NaN
# 4   422.325  1.5   0.5  1.71418   NaN
# 5   422.325    3   0.5  1.71418   NaN
# 6   422.325    6   0.5  1.71418   NaN
# 7   422.325   20   0.5  1.71418   NaN
# 8   550.776  1.5  0.99  1.69648   NaN
# 9   550.776    3  0.99  1.69648   NaN
# 10  550.776    6  0.99  1.69648   NaN
# 11  550.776   20  0.99  1.69648   NaN
# ==========init params=========
# m0 =   1.6606
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.2744
#
#
#  ==========fitted results==========
# optimization method = lbgfsb
# m0 =   1.6459
# b =   1.8901
# gamma_k =   0.0638
# sigma =   0.2799
#
#
#          LL        b         g        m sigma
# 0   143.498  1.89008  0.063751  1.54284   NaN
# 1   144.306  1.76005  0.063751  1.54288   NaN
# 2   145.193  1.63003  0.063751  1.54297   NaN
# 3   146.169      1.5  0.063751  1.54314   NaN
# 4   331.158  1.89008  0.526876  1.58396   NaN
# 5   337.083  1.76005  0.526876  1.58416   NaN
# 6    343.29  1.63003  0.526876  1.58436   NaN
# 7    349.79      1.5  0.526876  1.58458   NaN
# 8   500.926  1.89008      0.99  1.56998   NaN
# 9    502.95  1.76005      0.99  1.56936   NaN
# 10  504.861  1.63003      0.99  1.56877   NaN
# 11  506.631      1.5      0.99  1.56821   NaN
# ==========init params=========
# m0 =   1.5428
# b =   1.8901
# gamma_k =   0.0638
# sigma =   0.2799
#
#
#  ==========fitted results==========
# optimization method = lbgfsb
# m0 =   1.5560
# b =  10.9241
# gamma_k =   0.1094
# sigma =   0.2775
#
#
#          LL        b         g        m sigma
# 0   106.914  4.64137  0.109383  1.46571   NaN
# 1   111.617  10.9241  0.549691  1.49322   NaN
# 2   112.836  7.78275  0.109383  1.47187   NaN
# 3   119.069  7.78275  0.549691  1.49232   NaN
# 4   119.893  10.9241  0.109383  1.47927   NaN
# 5   132.454      1.5  0.109383  1.45905   NaN
# 6   149.674  4.64137  0.549691   1.4888   NaN
# 7   184.343  10.9241      0.99  1.50028   NaN
# 8   223.082  7.78275      0.99  1.50092   NaN
# 9   312.205  4.64137      0.99  1.50186   NaN
# 10  313.986      1.5  0.549691  1.49426   NaN
# 11  486.524      1.5      0.99  1.48151   NaN
# ==========init params=========
# m0 =   1.4657
# b =   4.6414
# gamma_k =   0.1094
# sigma =   0.2775
#
#
#  ==========fitted results==========
# optimization method = lbgfsb
# m0 =   1.4739
# b =   4.7589
# gamma_k =   0.1290
# sigma =   0.2929
#
#
#          LL        b         g        m sigma
# 0   95.1454  3.67258  0.128981  1.45376   NaN
# 1   96.3879  4.75888  0.128981  1.46536   NaN
# 2   97.9673  2.58629  0.128981   1.4312   NaN
# 3   105.586  4.75888  0.559491  1.43625   NaN
# 4   121.281  3.67258  0.559491  1.43513   NaN
# 5   124.789      1.5  0.128981  1.41798   NaN
# 6   164.405  2.58629  0.559491  1.43723   NaN
# 7   191.185  4.75888      0.99  1.45168   NaN
# 8   248.042  3.67258      0.99  1.45548   NaN
# 9    288.68      1.5  0.559491  1.45016   NaN
# 10  349.779  2.58629      0.99  1.45993   NaN
# 11  480.554      1.5      0.99  1.45195   NaN
# ==========init params=========
# m0 =   1.4538
# b =   3.6726
# gamma_k =   0.1290
# sigma =   0.2929
#
#
#  ==========fitted results==========
# optimization method = lbgfsb
# m0 =   1.4351
# b =   3.9485
# gamma_k =   0.1707
# sigma =   0.2635
#
#
#          LL        b         g        m sigma
# 0   90.6194  3.94846  0.580354  1.38383   NaN
# 1   92.2368  3.13231  0.170709  1.38819   NaN
# 2   92.3527  2.31615  0.170709  1.37106   NaN
# 3   95.6532  3.94846  0.170709  1.41211   NaN
# 4   98.9204  3.13231  0.580354  1.37589   NaN
# 5   120.494      1.5  0.170709  1.35922   NaN
# 6    133.33  2.31615  0.580354  1.37357   NaN
# 7   138.874  3.94846      0.99  1.38604   NaN
# 8   187.839  3.13231      0.99  1.38738   NaN
# 9   251.551      1.5  0.580354  1.37972   NaN
# 10  292.545  2.31615      0.99   1.3878   NaN
# 11  448.794      1.5      0.99  1.37253   NaN
# ==========init params=========
# m0 =   1.3838
# b =   3.9485
# gamma_k =   0.5804
# sigma =   0.2635
#
#
#  ==========fitted results==========
# optimization method = lbgfsb
# m0 =   1.3865
# b =   4.0226
# gamma_k =   0.4414
# sigma =   0.2510
#
#
#          LL        b         g        m sigma
# 0   87.7709  3.18173  0.441384  1.35244   NaN
# 1     89.61  4.02259  0.715692  1.35833   NaN
# 2   89.8965  4.02259  0.441384  1.37692   NaN
# 3   90.2635  3.18173  0.715692  1.34686   NaN
# 4   94.6983  2.34086  0.441384  1.33659   NaN
# 5   101.743  4.02259      0.99  1.35108   NaN
# 6   118.366  2.34086  0.715692  1.33971   NaN
# 7   127.692  3.18173      0.99  1.34778   NaN
# 8   182.164      1.5  0.441384  1.33459   NaN
# 9   218.076  2.34086      0.99  1.34893   NaN
# 10  269.549      1.5  0.715692  1.34311   NaN
# 11  437.121      1.5      0.99  1.33454   NaN
# ==========init params=========
# m0 =   1.3524
# b =   3.1817
# gamma_k =   0.4414
# sigma =   0.2510
#
#
#  ==========fitted results==========
# optimization method = lbgfsb
# m0 =   1.3738
# b =   4.0758
# gamma_k =   0.5239
# sigma =   0.2947
#
#
#          LL        b         g        m sigma
# 0   85.2493  3.21717  0.523879  1.34459   NaN
# 1   85.8995  3.21717  0.756939  1.33956   NaN
# 2    87.605  4.07576  0.756939  1.35539   NaN
# 3   89.3834  4.07576  0.523879  1.37385   NaN
# 4   91.1194  2.35859  0.523879  1.32858   NaN
# 5    92.927  4.07576      0.99  1.34219   NaN
# 6   105.332  2.35859  0.756939  1.33119   NaN
# 7     107.1  3.21717      0.99  1.33744   NaN
# 8   164.215  2.35859      0.99  1.34395   NaN
# 9   182.376      1.5  0.523879  1.33632   NaN
# 10  250.512      1.5  0.756939  1.34949   NaN
# 11  399.128      1.5      0.99  1.35984   NaN
# ==========init params=========
# m0 =   1.3446
# b =   3.2172
# gamma_k =   0.5239
# sigma =   0.2947
#
#
#  ==========fitted results==========
# optimization method = lbgfsb
# m0 =   1.3376
# b =   3.1110
# gamma_k =   0.5933
# sigma =   0.2819
#
#
#          LL        b         g        m sigma
# 0   83.8535  2.57403  0.593339  1.31348   NaN
# 1   85.3669  3.11104  0.791669  1.32381   NaN
# 2   86.1021  3.11104  0.593339  1.33508   NaN
# 3   86.1836  2.57403  0.791669  1.30929   NaN
# 4   92.3441  3.11104      0.99  1.31297   NaN
# 5   92.5538  2.03701  0.593339  1.30122   NaN
# 6   106.883  2.03701  0.791669  1.30412   NaN
# 7    107.19  2.57403      0.99   1.3095   NaN
# 8   165.652  2.03701      0.99  1.31518   NaN
# 9   166.033      1.5  0.593339  1.30687   NaN
# 10  219.419      1.5  0.791669  1.31633   NaN
# 11  351.663      1.5      0.99  1.32517   NaN
# ==========init params=========
# m0 =   1.3135
# b =   2.5740
# gamma_k =   0.5933
# sigma =   0.2819
#
#
#  ==========fitted results==========
# optimization method = lbgfsb
# m0 =   1.3192
# b =   2.7233
# gamma_k =   0.5950
# sigma =   0.2624
#
#
#          LL        b         g        m sigma
# 0   83.0951  2.31555  0.594994  1.29573   NaN
# 1   84.1791  2.72333  0.792497  1.30469   NaN
# 2   84.6198  2.31555  0.792497  1.28827   NaN
# 3   85.4583  2.72333  0.594994  1.31541   NaN
# 4   88.2352  1.90778  0.594994  1.27847   NaN
# 5   90.1565  2.72333      0.99  1.29044   NaN
# 6   98.8541  1.90778  0.792497  1.27921   NaN
# 7   100.557  2.31555      0.99  1.28459   NaN
# 8   139.933      1.5  0.594994  1.27734   NaN
# 9   150.239  1.90778      0.99  1.28663   NaN
# 10   184.71      1.5  0.792497  1.28452   NaN
# 11  311.025      1.5      0.99  1.29171   NaN
# ==========init params=========
# m0 =   1.2957
# b =   2.3156
# gamma_k =   0.5950
# sigma =   0.2624
#
#
#  ==========fitted results==========
# optimization method = lbgfsb
# m0 =   1.2958
# b =   2.3507
# gamma_k =   0.6309
# sigma =   0.2594
#
#
#          LL        b         g        m sigma
# 0   83.0339   2.0671  0.630917  1.27587   NaN
# 1   83.7779  2.35065  0.810458  1.28316   NaN
# 2   84.2335  2.35065  0.630917  1.29247   NaN
# 3   85.0632   2.0671  0.810458  1.27053   NaN
# 4   88.6875  1.78355  0.630917  1.26305   NaN
# 5   90.4527  2.35065      0.99  1.27252   NaN
# 6   99.0758  1.78355  0.810458  1.26376   NaN
# 7   102.568   2.0671      0.99   1.2683   NaN
# 8   126.915      1.5  0.630917  1.26146   NaN
# 9   148.104  1.78355      0.99  1.27044   NaN
# 10  162.342      1.5  0.810458  1.26726   NaN
# 11  272.036      1.5      0.99   1.2755   NaN
# ==========init params=========
# m0 =   1.2759
# b =   2.0671
# gamma_k =   0.6309
# sigma =   0.2594
#
#
#  ==========fitted results==========
# optimization method = lbgfsb
# m0 =   1.2777
# b =   2.1084
# gamma_k =   0.6439
# sigma =   0.2616
#          m0          b   gamma_k     sigma          LL
# 0  1.645898   1.890077  0.063751  0.279945  271.002919
# 1  1.555995  10.924122  0.109383  0.277510  129.793835
# 2  1.473888   4.758877  0.128981  0.292861  105.152252
# 3  1.435084   3.948461  0.170709  0.263496   91.314827
# 4  1.386468   4.022594  0.441384  0.251030   88.401337
# 5  1.373756   4.075756  0.523879  0.294691   84.719261
# 6  1.337553   3.111044  0.593339  0.281890   84.022924
# 7  1.319242   2.723327  0.594994  0.262433   83.389001
# 8  1.295804   2.350653  0.630917  0.259362   83.046985
# 9  1.277733   2.108387  0.643876  0.261617   82.989752

# %% [markdown]
# ## export set of params to .xlsx

# %%
output
# Out:
#          m0          b   gamma_k     sigma           LL
# 0  1.724131   1.500000  0.129090  0.608754  5967.526625
# 1  1.673841  21.302960  0.245566  0.587575  5727.634096
# 2  1.649398  15.651842  0.324070  0.508946  5625.049883
# 3  1.609224  12.765558  0.659629  0.467231  5570.547290
# 4  1.579176  11.205719  0.650867  0.420608  5538.345034
# 5  1.533688   8.403110  0.792995  0.467599  5523.897339
# 6  1.585299  49.864345  0.956547  0.294231  5563.227019
# 7  1.609050  44.049004  0.392482  0.471145  5586.177678
# 8  1.460462   5.237711  0.959639  0.522382  5515.864436
# 9  1.402961   3.450525  0.981728  0.370388  5514.933868

# %%
name = 'GBP'
name_L = 'Output'.join((date.today().strftime('%y%m%d'),op_methods+name+'5.xlsx'))
writer = pd.ExcelWriter(name_L)
print(name_L)
output.to_excel(writer, 'Sheet1')
writer.save()
# Out:
# 180218OutputslsqpGBP5.xlsx

# %% [markdown]
# # Verify likelihood function

# %%
op_methods = 'lbfgsb'
row = 1
dum_data = raw[row]
returns = np.log(1+dum_data['Column2'].pct_change().dropna())
returns = returns
a = returns.to_frame()
data = a['Column2']

MSM_likelihood_new(1.782,134.2,0.345,0.538, 2, data*100)
# Out:
# 6102.1694666264148

# %% [markdown]
# # Fit data

# %% [markdown]
# ## FIT for forecast

# %%
row = 0
op_methods = 'slsqp'
predict_period = 1
kbar = 10

starting_index = 3000
dum_data = raw[row]
returns = np.log(1+dum_data['Column2'].pct_change().dropna())
a = returns.to_frame()
data = a['Column2']*100
LB = [1, 1, 0.001, 0.0001]
UB = [1.99, 50, 0.99999, 50]
startingvals = []
data_fit = data[:starting_index]

# fit params

result = MSM_fitdata(data_fit, kbar, LB ,UB,op_methods, startingvals)
#re2 = MSM_likelihood_new(result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value,  kbar, data_fit)
rez = result.params
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-67ab611e71c4> in <module>()
#      16 # fit params
#      17
# ---> 18 result = MSM_fitdata(data_fit, kbar, LB ,UB,op_methods, startingvals)
#      19 #re2 = MSM_likelihood_new(result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value,  kbar, data_fit)
#      20 rez = result.params
#
# <ipython-input-5-44fb0eecbb52> in MSM_fitdata(data, kbar, LB, UB, op_methods, startingvals)
#      13     """
#      14
# ---> 15     input_param, LLS = MSM_starting_values(data, startingvals, kbar)
#      16         # print('LL = %8.4f' % LLS.loc[0, 'LL'])
#      17
#
# <ipython-input-3-9741c784fec9> in MSM_starting_values(data, startingvals, kbar)
#      45             a_m0 = fminbound(MSM_likelihood_new, 1.2, 1.8,
#      46                              args=(b[i], g[j], sigma, kbar, data),
# ---> 47                              xtol=1e-05, maxfun=500, full_output=True)  # , disp=3)
#      48             LL_storage.loc[len(LL_storage), 'LL'] = a_m0[1]
#      49             LL_storage.loc[len(LL_storage) - 1, 'b'] = b[i]
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in fminbound(func, x1, x2, args, xtol, maxfun, full_output, disp)
#    1617                'disp': disp}
#    1618
# -> 1619     res = _minimize_scalar_bounded(func, (x1, x2), args, **options)
#    1620     if full_output:
#    1621         return res['x'], res['fun'], res['status'], res['nfev']
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_scalar_bounded(func, bounds, args, xatol, maxiter, disp, **unknown_options)
#    1714         si = numpy.sign(rat) + (rat == 0)
#    1715         x = xf + si * numpy.max([numpy.abs(rat), tol1])
# -> 1716         fu = func(x, *args)
#    1717         num += 1
#    1718         fmin_data = (num, x, fu)
#
# <ipython-input-4-1ee095e55a09> in MSM_likelihood_new(*args)
#     105         return g_m
#     106
# --> 107     A, gamma = transition_mat(A_temp, b, gamma_k, kbar)
#     108     g_m = gofm(m0, kbar)
#     109     T = len(data)
#
# <ipython-input-4-1ee095e55a09> in transition_mat(A_temp, b, gamma_k, kbar)
#      77         for i in range(0, 2 ** (kbar - 1)):
#      78             for j in range(i, 2 ** (kbar - 1)):
# ---> 79                 A[kbar2 - i - 1, j] = prob[kbar2 - int(A[i, j]) - 1, 0]
#      80                 A[kbar2 - j - 1, i] = A[kbar2 - i - 1, j]
#      81                 A[j, kbar2 - i - 1] = A[kbar2 - i - 1, j]
#
# KeyboardInterrupt:

# %% [markdown]
# ### Chain forecast

# %%
row = 3
op_methods = 'slsqp'
predict_period = 1

starting_index = 3000
dum_data = raw[row]
returns = np.log(1+dum_data['Column2'].pct_change().dropna())
a = returns.to_frame()
data = a['Column2']*100
LB = [1, 1, 0.001, 0.0001]
UB = [1.99, 50, 0.99999, 50]
startingvals = []
data_fit = data[:starting_index]

# fit params

for i in range(0,10):
    kbar = i+1
    if kbar >1 and bool(result):
        startingvals = [result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value]
    result = MSM_fitdata(data_fit, kbar, LB ,UB,op_methods, startingvals)
    rez = result.params
    re2 = MSM_likelihood_new(result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,
                             result.params['sigma'].value,  kbar, data_fit
                            )
    output.loc[i,"LL"] = re2
    for element in result.params:
        output.loc[i,element] = result.params[element].value
# Out:
#          LL    b     g        m sigma
# 0  -350.937  1.5   0.1  1.66302   NaN
# 1  -350.937    3   0.1  1.66302   NaN
# 2  -350.937    6   0.1  1.66302   NaN
# 3  -350.937   20   0.1  1.66302   NaN
# 4  -279.652  1.5   0.5  1.71289   NaN
# 5  -279.652    3   0.5  1.71289   NaN
# 6  -279.652    6   0.5  1.71289   NaN
# 7  -279.652   20   0.5  1.71289   NaN
# 8  -213.158  1.5  0.99  1.69334   NaN
# 9  -213.158    3  0.99  1.69334   NaN
# 10 -213.158    6  0.99  1.69334   NaN
# 11 -213.158   20  0.99  1.69334   NaN
# ==========init params=========
# m0 =   1.6630
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.2372
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.6694
# b =   1.5000
# gamma_k =   0.0720
# sigma =   0.2572
#
#
#          LL    b         g        m sigma
# 0  -421.009  1.5  0.072032  1.54328   NaN
# 1  -421.009  1.5  0.072032  1.54328   NaN
# 2  -421.009  1.5  0.072032  1.54328   NaN
# 3  -421.009  1.5  0.072032  1.54328   NaN
# 4  -318.226  1.5  0.531016  1.60865   NaN
# 5  -318.226  1.5  0.531016  1.60865   NaN
# 6  -318.226  1.5  0.531016  1.60865   NaN
# 7  -318.226  1.5  0.531016  1.60865   NaN
# 8  -233.999  1.5      0.99  1.60174   NaN
# 9  -233.999  1.5      0.99  1.60174   NaN
# 10 -233.999  1.5      0.99  1.60174   NaN
# 11 -233.999  1.5      0.99  1.60174   NaN
# ==========init params=========
# m0 =   1.5433
# b =   1.5000
# gamma_k =   0.0720
# sigma =   0.2572
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5701
# b =   5.7991
# gamma_k =   0.0923
# sigma =   0.2805
#
#
#          LL        b          g        m sigma
# 0  -424.227  5.79914  0.0923191  1.58295   NaN
# 1  -424.089  4.36609  0.0923191  1.57819   NaN
# 2  -423.865  2.93305  0.0923191   1.4686   NaN
# 3  -420.378      1.5  0.0923191  1.48005   NaN
# 4  -415.474  5.79914    0.54116  1.51482   NaN
# 5   -405.59  4.36609    0.54116  1.51994   NaN
# 6  -382.934  2.93305    0.54116   1.5299   NaN
# 7  -339.631  5.79914       0.99  1.54829   NaN
# 8  -326.458      1.5    0.54116  1.55325   NaN
# 9  -312.177  4.36609       0.99  1.55741   NaN
# 10 -270.856  2.93305       0.99  1.56592   NaN
# 11 -223.722      1.5       0.99  1.56506   NaN
# ==========init params=========
# m0 =   1.5830
# b =   5.7991
# gamma_k =   0.0923
# sigma =   0.2805
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5391
# b =   5.8917
# gamma_k =   0.1180
# sigma =   0.2315
#
#
#          LL        b         g        m sigma
# 0  -435.116  2.96391   0.11799   1.4262   NaN
# 1  -434.263  5.89174  0.553995  1.45088   NaN
# 2  -431.658      1.5   0.11799  1.41377   NaN
# 3  -430.851  4.42783   0.11799   1.4346   NaN
# 4  -430.379  4.42783  0.553995  1.43788   NaN
# 5  -426.668  5.89174   0.11799  1.44581   NaN
# 6  -419.359  2.96391  0.553995  1.42218   NaN
# 7  -404.619  5.89174      0.99  1.42716   NaN
# 8  -388.544  4.42783      0.99   1.4293   NaN
# 9  -363.875      1.5  0.553995  1.43045   NaN
# 10 -346.557  2.96391      0.99  1.43462   NaN
# 11 -265.443      1.5      0.99  1.41946   NaN
# ==========init params=========
# m0 =   1.4262
# b =   2.9639
# gamma_k =   0.1180
# sigma =   0.2315
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4986
# b =   3.4864
# gamma_k =   0.1087
# sigma =   0.3010
#
#
#          LL        b         g        m sigma
# 0  -434.466  2.16215   0.10867  1.41391   NaN
# 1   -433.39  2.82429   0.10867  1.41517   NaN
# 2  -431.406  3.48644   0.10867   1.4167   NaN
# 3  -430.064      1.5   0.10867  1.41374   NaN
# 4  -426.753  3.48644  0.549335  1.42454   NaN
# 5  -420.802  2.82429  0.549335  1.42078   NaN
# 6  -402.411  2.16215  0.549335  1.43043   NaN
# 7  -381.602  3.48644      0.99  1.44243   NaN
# 8  -351.713  2.82429      0.99  1.45708   NaN
# 9  -349.931      1.5  0.549335  1.45825   NaN
# 10 -298.527  2.16215      0.99  1.47795   NaN
# 11 -226.901      1.5      0.99   1.4932   NaN
# ==========init params=========
# m0 =   1.4139
# b =   2.1621
# gamma_k =   0.1087
# sigma =   0.3010
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.3917
# b =   2.6397
# gamma_k =   0.2394
# sigma =   0.2385
#
#
#          LL        b        g        m sigma
# 0  -439.933  2.25982  0.23938  1.36234   NaN
# 1  -439.504  1.87991  0.23938  1.34979   NaN
# 2  -438.313  2.63973  0.23938  1.37905   NaN
# 3  -435.985  2.63973  0.61469  1.35453   NaN
# 4  -432.259      1.5  0.23938  1.34359   NaN
# 5  -431.026  2.25982  0.61469  1.35042   NaN
# 6  -418.246  1.87991  0.61469  1.35065   NaN
# 7  -401.861  2.63973     0.99  1.35714   NaN
# 8  -387.465      1.5  0.61469  1.35889   NaN
# 9  -379.619  2.25982     0.99  1.36244   NaN
# 10 -342.034  1.87991     0.99  1.36776   NaN
# 11 -292.334      1.5     0.99  1.36468   NaN
# ==========init params=========
# m0 =   1.3623
# b =   2.2598
# gamma_k =   0.2394
# sigma =   0.2385
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.3558
# b =   2.1694
# gamma_k =   0.2541
# sigma =   0.2294
#
#
#          LL        b         g        m sigma
# 0   -440.35  1.94626  0.254084  1.33044   NaN
# 1  -439.933  1.72313  0.254084  1.32111   NaN
# 2  -439.221  2.16939  0.254084  1.34204   NaN
# 3  -435.924  2.16939  0.622042  1.32312   NaN
# 4   -435.77      1.5  0.254084  1.31514   NaN
# 5  -431.118  1.94626  0.622042  1.32032   NaN
# 6  -420.864  1.72313  0.622042  1.32011   NaN
# 7  -400.801      1.5  0.622042  1.32391   NaN
# 8  -397.857  2.16939      0.99  1.32722   NaN
# 9  -377.314  1.94626      0.99  1.33041   NaN
# 10 -347.156  1.72313      0.99   1.3329   NaN
# 11 -309.265      1.5      0.99  1.33067   NaN
# ==========init params=========
# m0 =   1.3304
# b =   1.9463
# gamma_k =   0.2541
# sigma =   0.2294
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.3268
# b =   1.8993
# gamma_k =   0.2685
# sigma =   0.2283
#
#
#          LL        b         g        m sigma
# 0  -440.448  1.76618  0.268459  1.30752   NaN
# 1  -440.176  1.63309  0.268459  1.30043   NaN
# 2  -439.872  1.89927  0.268459  1.31681   NaN
# 3  -438.105      1.5  0.268459  1.29553   NaN
# 4  -435.356  1.89927   0.62923  1.30025   NaN
# 5  -431.255  1.76618   0.62923   1.2986   NaN
# 6  -423.887  1.63309   0.62923  1.29857   NaN
# 7  -411.602      1.5   0.62923  1.30063   NaN
# 8  -394.047  1.89927      0.99  1.30662   NaN
# 9  -377.012  1.76618      0.99   1.3091   NaN
# 10 -354.549  1.63309      0.99  1.31106   NaN
# 11 -327.384      1.5      0.99  1.31088   NaN
# ==========init params=========
# m0 =   1.3075
# b =   1.7662
# gamma_k =   0.2685
# sigma =   0.2283
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.3059
# b =   1.7351
# gamma_k =   0.2729
# sigma =   0.2308
#
#
#          LL        b         g        m sigma
# 0  -440.645   1.6567  0.272882  1.29195   NaN
# 1  -440.557  1.57835  0.272882  1.28648   NaN
# 2  -440.378  1.73505  0.272882  1.29851   NaN
# 3  -439.808      1.5  0.272882  1.28217   NaN
# 4  -435.051  1.73505  0.631441  1.28301   NaN
# 5  -432.085   1.6567  0.631441  1.28206   NaN
# 6  -427.484  1.57835  0.631441  1.28203   NaN
# 7  -420.711      1.5  0.631441  1.28305   NaN
# 8  -392.013  1.73505      0.99   1.2913   NaN
# 9  -379.425   1.6567      0.99  1.29336   NaN
# 10 -364.101  1.57835      0.99  1.29523   NaN
# 11 -346.216      1.5      0.99  1.29633   NaN
# ==========init params=========
# m0 =   1.2919
# b =   1.6567
# gamma_k =   0.2729
# sigma =   0.2308
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.2915
# b =   1.6467
# gamma_k =   0.2796
# sigma =   0.2346
#
#
#          LL        b         g        m sigma
# 0  -440.839  1.54889  0.279606  1.27595   NaN
# 1  -440.772  1.59778  0.279606  1.27992   NaN
# 2   -440.65      1.5  0.279606  1.27252   NaN
# 3  -440.544  1.64667  0.279606  1.28449   NaN
# 4  -435.498  1.64667  0.634803  1.26989   NaN
# 5  -433.604  1.59778  0.634803  1.26914   NaN
# 6  -430.933  1.54889  0.634803   1.2689   NaN
# 7  -427.292      1.5  0.634803  1.26922   NaN
# 8  -394.492  1.64667      0.99  1.27855   NaN
# 9  -385.725  1.59778      0.99  1.28032   NaN
# 10 -375.506  1.54889      0.99  1.28208   NaN
# 11 -363.841      1.5      0.99  1.28367   NaN
# ==========init params=========
# m0 =   1.2759
# b =   1.5489
# gamma_k =   0.2796
# sigma =   0.2346
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.2766
# b =   1.5693
# gamma_k =   0.2899
# sigma =   0.2345

# %%
pi_mat, A, sigma, s = MSM_likelihood_wantto_forecast(rez, kbar, data, predict_period)

# %% [markdown]
# ## PICKLE for import/export model

# %% [markdown]
# ### save

# %%
import pickle
from datetime import date
# obj0, obj1, obj2 are created here...

data_name = 'DM'
model_name = ''.join((date.today().strftime('%y%m%d'),"_"+ str(kbar)+ op_methods+ str(data_name) + '.pkl'))
# Saving the objects:
with open(model_name, 'wb') as f: 
    pickle.dump(result.params, f)
    print(model_name)
# Out:
# 180225_10slsqpDM.pkl

# %% [markdown]
# ### load

# %%
import pickle
# # Getting back the objects:
with open('180219_10slsqpDM.pkl', 'rb') as f:  # Python 3: open(..., 'rb')
    rez_2 = pickle.load(f)

# %%
rez

# %%
rez_2
# Out:
# Parameters([('m0', <Parameter 'm0', 1.6299929540997213, bounds=[1:1.99]>),
#             ('b', <Parameter 'b', 4.4117265184781624, bounds=[1:50]>),
#             ('gamma_k',
#              <Parameter 'gamma_k', 0.70285396272487677, bounds=[0.001:0.99999]>),
#             ('sigma',
#              <Parameter 'sigma', 0.58279795462479345, bounds=[0.0001:50]>)])

# %% [markdown]
# ## forecast process 1 day

# %%
# df for OLS
Pdict = df()
Pdict["vol"] = []
predict_period = 1

vol = np.ones((predict_period,1))
vol = vol.astype(float)
for i in range(starting_index,len(pi_mat)-1):
    
    state_now = pi_mat[i , :]
    for t in range(0,predict_period):
        vol[t,0] = np.inner(np.matmul(state_now, np.linalg.matrix_power(A, t+1)),s[1,:])
    Pdict.loc[i,"vol"] = sum(vol)

# %%
returns = np.log(1+dum_data['Column2'].pct_change().dropna())
a = returns.to_frame()
data = a['Column2']*100
rsq = data[starting_index-2:].shift(-predict_period)
dfrsq = rsq.to_frame()
Pdict['real']=dfrsq**2
Pdict
# Out:
#            vol      real
# 3000  0.263898  0.238701
# 3001  0.303271  0.003385
# 3002  0.278490  0.005282
# 3003  0.256471  0.053919
# 3004  0.256532  0.480795
# 3005  0.342735  0.063307
# 3006  0.325556  0.000206
# 3007  0.295745  0.000000
# 3008  0.268269  0.070364
# 3009  0.272440  0.082254
# 3010  0.278031  0.043450
# 3011  0.270168  0.005181
# 3012  0.250052  0.013288
# 3013  0.235893  0.053337
# 3014  0.241437  0.020853
# 3015  0.232276  0.119524
# 3016  0.259332  0.004185
# 3017  0.241098  0.046368
# 3018  0.241762  0.267886
# 3019  0.297877  0.001298
# 3020  0.273634  0.016840
# 3021  0.257019  0.000208
# 3022  0.235482  0.373813
# 3023  0.318034  0.185925
# 3024  0.329380  0.011683
# 3025  0.303038  0.241545
# 3026  0.333336  0.015190
# 3027  0.307450  0.001316
# 3028  0.280038  0.021034
# 3029  0.263685  0.015157
# ...        ...       ...
# 7018  0.253018  0.704806
# 7019  0.379132  0.001052
# 7020  0.344104  0.033054
# 7021  0.320981  0.028600
# 7022  0.300669  0.022453
# 7023  0.281889  0.006116
# 7024  0.259458  0.086195
# 7025  0.272671  0.068127
# 7026  0.274935  0.001062
# 7027  0.253293  0.180310
# 7028  0.292113  0.002099
# 7029  0.269459  0.000171
# 7030  0.247582  0.185670
# 7031  0.289836  0.026569
# 7032  0.275146  0.000681
# 7033  0.253192  0.173770
# 7034  0.289558  0.000169
# 7035  0.266415  0.013708
# 7036  0.250501  0.046029
# 7037  0.250118  0.427438
# 7038  0.333693  0.026060
# 7039  0.311130  0.040215
# 7040  0.295953  0.032934
# 7041  0.281563  0.390272
# 7042  0.347317  0.324377
# 7043  0.372995  0.188564
# 7044  0.372369  0.117160
# 7045  0.361371  0.002117
# 7046  0.328045  0.461645
# 7047  0.389005  0.292996
#
# [4048 rows x 2 columns]

# %%
rsq = data[starting_index-2:]**2
rsq
# Out:
# 2999    0.127299
# 3000    0.001578
# 3001    0.311108
# 3002    1.419519
# 3003    0.303802
# 3004    0.954062
# 3005    0.434004
# 3006    2.071969
# 3007    2.371633
# 3008    1.316507
# 3009    0.055844
# 3010    0.759151
# 3011    0.177033
# 3012    0.110339
# 3013    0.014044
# 3014    1.389559
# 3015    0.006108
# 3016    2.407529
# 3017    0.331438
# 3018    5.251678
# 3019    0.620733
# 3020    0.000000
# 3021    0.024187
# 3022    1.013223
# 3023    0.214667
# 3024    1.810096
# 3025    0.118497
# 3026    0.005876
# 3027    0.442175
# 3028    1.173901
#           ...
# 7269    0.057591
# 7270    0.009201
# 7271    0.018822
# 7272    0.020750
# 7273    0.091236
# 7274    0.048297
# 7275    0.078888
# 7276    0.015181
# 7277    0.141379
# 7278    0.041991
# 7279    0.000421
# 7280    0.013533
# 7281    0.045148
# 7282    0.016974
# 7283    0.005678
# 7284    0.001687
# 7285    0.269198
# 7286    0.016716
# 7287    0.000740
# 7288    0.031190
# 7289    0.101417
# 7290    0.336519
# 7291    0.001131
# 7292    0.533191
# 7293    0.001113
# 7294    0.210995
# 7295    0.143872
# 7296    2.082160
# 7297    0.198803
# 7298    0.068664
# Name: Column2, Length: 4300, dtype: float64

# %% [markdown]
# ## Regression

# %% [markdown]
# ### stats model

# %%
import statsmodels.api as sm

print('dataset = %1.0f' %row)

for ele in rez:
    print(ele,' = %8.4f'  %rez[ele].value)
x = Pdict.loc[:,'vol'].values.reshape(len(Pdict),1)
y = Pdict['real']

x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# print("MODEL MSE",est2.mse_model)
print("MODEL MSE",est2.mse_resid)
print("MODEL TSE",est2.mse_total)
# Out:
# dataset = 3
# m0  =   1.2766
# b  =   1.5693
# gamma_k  =   0.2899
# sigma  =   0.2345
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   real   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     185.1
# Date:                Sun, 25 Feb 2018   Prob (F-statistic):           3.05e-41
# Time:                        14:45:08   Log-Likelihood:                 976.51
# No. Observations:                4048   AIC:                            -1949.
# Df Residuals:                    4046   BIC:                            -1936.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0524      0.011     -4.835      0.000      -0.074      -0.031
# x1             0.5348      0.039     13.603      0.000       0.458       0.612
# ==============================================================================
# Omnibus:                     5091.925   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           966124.741
# Skew:                           6.780   Prob(JB):                         0.00
# Kurtosis:                      77.459   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MODEL MSE 0.0361582766155
# MODEL TSE 0.0378026954695

# %% [markdown]
# ## EXPORT Result!

# %%
# output = df()
#

# %%
for element in result.params:
    output.loc[row,element] = result.params[element].value

output.loc[row,'Slope'] = sum(regr.coef_)
output.loc[row,'intercept'] =  regr.intercept_
output.loc[row,'MSE'] = mean_squared_error(y, x)
output.loc[row,'R_sq'] = r2_score(y, x)

writer = pd.ExcelWriter('Output'.join((date.today().strftime('%y%m%d'),'ALL_REG.xlsx')))
output.to_excel(writer, 'Sheet1')
writer.save()

# %%
result.params
# Out:
# Parameters([('m0', <Parameter 'm0', 1.629998096335135, bounds=[1:1.99]>),
#             ('b', <Parameter 'b', 4.4120315416646161, bounds=[1:50]>),
#             ('gamma_k',
#              <Parameter 'gamma_k', 0.70287857197217063, bounds=[0.001:0.99999]>),
#             ('sigma',
#              <Parameter 'sigma', 0.58282108145794298, bounds=[0.0001:50]>)])

# %%
output
# Out:
#          m0          b   gamma_k     sigma           LL
# 0  1.856799   1.500000  0.151344  0.559417  2165.156704
# 1  1.790297  18.353692  0.223294  0.518750  1994.989617
# 2  1.760918  14.145956  0.332085  0.448827  1918.480683
# 3  1.704834   5.141529  0.170362  0.540188  1886.691143
# 4  1.636330   5.037106  0.384254  0.447685  1877.105656
# 5  1.600150   5.596331  0.688778  0.524212  1872.450342
# 6  1.559214   4.162739  0.673908  0.435483  1869.788388
# 7  1.512173   3.358684  0.800145  0.436961  1870.498799
# 8  1.484956   2.810734  0.792318  0.423587  1870.388228
# 9  1.456981   2.539776  0.838297  0.410643  1870.705819

# %% [markdown]
# # Gold Data

# %% [markdown]
# ## input

# %%
GLD.loc[8000,:]
# Out:
# Date                                                                                                                 2000-01-02
# Last Price                                                                                                               410,05
# index                                                                                                                    410.05
# log return                                                                                                            -0.148025
# The Gold Spot price is quoted as US Dollars per Troy Ounce.  Type ALLQ <GO> for the list of price contributors                1
# Name: 8000, dtype: object

# %%
GVZ = pd.read_excel('Data_GVZ_GLD_long.xlsx','GVZ')
GLD = pd.read_excel('Data_GVZ_GLD_long.xlsx','GLD')

GLD_r = GLD.loc[:,'log return'].dropna()
GLD_date = GLD.loc[:,'Date'].dropna()
GLD_data = GLD.loc[:,'index'].dropna()

plt.plot(GLD_date.iloc[:-1],200*GLD_r)
plt.plot(GLD_date,GLD_data)
plt.title('GLD data')


data = GLD_r[::-1]
data = data.reset_index(drop = True)
plt.show()

# %% [markdown]
# ## output

# %%
output = df()
output["m0"] = []
output["b"] = []
output["gamma_k"]=[]
output["sigma"] = []
output["LL"] = []
result = []

startingvals = []#[1.2, 1.2, 0.5 , 1.2 ]
LB = [1, 1, 0.001, 0.0001]
UB = [1.99, 50, 0.99999, 50]

# %%
data = data[3000:]

# %% [markdown]
# ## Fit data

# %%
op_methods = 'slsqp'
data2 = data#[::-1]
startingvals = []

for i in range(0,10):
    kbar = i+1
    if kbar >1 and bool(result):
        startingvals = [result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value]
    result = MSM_fitdata(data, kbar, LB ,UB,op_methods, startingvals)
    re2 = MSM_likelihood_new(result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value,  kbar, data2)
    output.loc[i,"LL"] = re2
    for element in result.params:
        output.loc[i,element] = result.params[element].value
        
writer = pd.ExcelWriter('Output'.join((date.today().strftime('%y%m%d'),op_methods+'GLDvaryk.xlsx')))
output.to_excel(writer, 'Sheet1')
writer.save()
        
output
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-effda8ec5cef> in <module>()
#       7     if kbar >1 and bool(result):
#       8         startingvals = [result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value]
# ----> 9     result = MSM_fitdata(data, kbar, LB ,UB,op_methods, startingvals)
#      10     re2 = MSM_likelihood_new(result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value,  kbar, data2)
#      11     output.loc[i,"LL"] = re2
#
# <ipython-input-5-437be2723c0e> in MSM_fitdata(data, kbar, LB, UB, op_methods, startingvals)
#      13     """
#      14
# ---> 15     input_param, LLS = MSM_starting_values(data, startingvals, kbar)
#      16         # print('LL = %8.4f' % LLS.loc[0, 'LL'])
#      17
#
# <ipython-input-3-a2a5ed9584ab> in MSM_starting_values(data, startingvals, kbar)
#      45             a_m0 = fminbound(MSM_likelihood_new, 1.2, 1.8,
#      46                              args=(b[i], g[j], sigma, kbar, data),
# ---> 47                              xtol=1e-05, maxfun=500, full_output=True)  # , disp=3)
#      48             LL_storage.loc[len(LL_storage), 'LL'] = a_m0[1]
#      49             LL_storage.loc[len(LL_storage) - 1, 'b'] = b[i]
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in fminbound(func, x1, x2, args, xtol, maxfun, full_output, disp)
#    1617                'disp': disp}
#    1618
# -> 1619     res = _minimize_scalar_bounded(func, (x1, x2), args, **options)
#    1620     if full_output:
#    1621         return res['x'], res['fun'], res['status'], res['nfev']
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_scalar_bounded(func, bounds, args, xatol, maxiter, disp, **unknown_options)
#    1714         si = numpy.sign(rat) + (rat == 0)
#    1715         x = xf + si * numpy.max([numpy.abs(rat), tol1])
# -> 1716         fu = func(x, *args)
#    1717         num += 1
#    1718         fmin_data = (num, x, fu)
#
# <ipython-input-4-b6fb5076bad8> in MSM_likelihood_new(*args)
#     138             pi_mat[t + 1, :] = np.divide(C, ft)
#     139
# --> 140         LLs[t] = np.log(np.dot(w_t[t, :], piA))
#     141
#     142     LL = -sum(LLs)
#
# KeyboardInterrupt:

# %% [markdown]
# # GLD Forecast

# %% [markdown]
# ### drop index

# %%
GVZ_date = GVZ.loc[:,'Date'].dropna()
GVZ_data = GVZ.loc[:,'index'].dropna()
GLD_date = GLD.loc[:,'Date'].dropna()
GLD_data = GLD.loc[:,'index'].dropna()

# GVZ/GLD use for regression (new -> old)
GVZ_date = GVZ_date.drop(GVZ_date.index[0])
GVZ_date = GVZ_date.reset_index(drop=True)
# for small date
GVZ_date = GVZ_date[0:1000]
GVZ_data = GVZ_data.reset_index(drop=True)

GLD_data = GLD_data.drop(GLD_date.index[0])
GLD_data = GLD_data.reset_index(drop=True)
GLD_date = GLD_date.drop(GLD_date.index[0])
GLD_date = GLD_date.drop(GLD_date.index[len(GLD_date)-1])
GLD_date = GLD_date.reset_index(drop=True)

# all to df
df_reg = GVZ_date.to_frame()
df_reg["GVZ"] = GVZ_data
df_reg["GLD"] = GLD_data

# [old -> new]
df_reg = df_reg[::-1]
# df_reg

# New data drop the first (last date) because there are no GVZ data
# data use for MSM function (old -> new)
data = GLD_r
data = data.drop(data.index[len(data)-1])
data = data.reset_index(drop=True)
data_fit = data.drop(data.index[0:len(df_reg)])

# %% [markdown]
# ## chain forecast

# %% [markdown]
# ### param

# %%
op_methods = 'slsqp'
predict_period = 1
kbar = 10
LB = [1, 1, 0.001, 0.0001]
UB = [1.99, 50, 0.99999, 50]
startingvals = []

# %% [markdown]
# ### fit param

# %%
# fit params
for i in range(0,10):
    kbar = i+1
    if kbar >1 and bool(result):
        startingvals = [result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,result.params['sigma'].value]
    result = MSM_fitdata(data_fit, kbar, LB ,UB,op_methods, startingvals)
    rez = result.params
    re2 = MSM_likelihood_new(result.params['m0'].value,result.params['b'].value,result.params['gamma_k'].value,
                             result.params['sigma'].value,  kbar, data_fit
                            )
    output.loc[i,"LL"] = re2
    for element in result.params:
        output.loc[i,element] = result.params[element].value
# Out:
#          LL    b     g        m sigma
# 0   6352.21  1.5   0.1  1.75295   NaN
# 1   6352.21    3   0.1  1.75295   NaN
# 2   6352.21    6   0.1  1.75295   NaN
# 3   6352.21   20   0.1  1.75295   NaN
# 4   6649.02  1.5   0.5  1.79999   NaN
# 5   6649.02    3   0.5  1.79999   NaN
# 6   6649.02    6   0.5  1.79999   NaN
# 7   6649.02   20   0.5  1.79999   NaN
# 8   6961.54  1.5  0.99  1.79999   NaN
# 9   6961.54    3  0.99  1.79999   NaN
# 10  6961.54    6  0.99  1.79999   NaN
# 11  6961.54   20  0.99  1.79999   NaN
# ==========init params=========
# m0 =   1.7530
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.5465
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.7737
# b =   1.5000
# gamma_k =   0.0470
# sigma =   0.6649
#
#
#          LL    b          g        m sigma
# 0   5891.15  1.5  0.0470288  1.66967   NaN
# 1   5891.15  1.5  0.0470288  1.66967   NaN
# 2   5891.15  1.5  0.0470288  1.66967   NaN
# 3   5891.15  1.5  0.0470288  1.66967   NaN
# 4   6335.53  1.5   0.518514  1.76591   NaN
# 5   6335.53  1.5   0.518514  1.76591   NaN
# 6   6335.53  1.5   0.518514  1.76591   NaN
# 7   6335.53  1.5   0.518514  1.76591   NaN
# 8   6782.08  1.5       0.99  1.78732   NaN
# 9   6782.08  1.5       0.99  1.78732   NaN
# 10  6782.08  1.5       0.99  1.78732   NaN
# 11  6782.08  1.5       0.99  1.78732   NaN
# ==========init params=========
# m0 =   1.6697
# b =   1.5000
# gamma_k =   0.0470
# sigma =   0.6649
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.6947
# b =  12.1864
# gamma_k =   0.1347
# sigma =   0.6207
#
#
#          LL        b         g        m sigma
# 0   5688.86  12.1864  0.134737  1.62257   NaN
# 1   5690.22  8.62424  0.134737  1.61938   NaN
# 2   5700.71  5.06212  0.134737  1.61059   NaN
# 3   5719.26  12.1864  0.562369  1.62605   NaN
# 4   5742.01  8.62424  0.562369  1.62634   NaN
# 5   5807.98      1.5  0.134737  1.60826   NaN
# 6   5811.85  5.06212  0.562369  1.62904   NaN
# 7   5870.97  12.1864      0.99  1.64269   NaN
# 8   5950.92  8.62424      0.99  1.64819   NaN
# 9   6145.18  5.06212      0.99   1.6608   NaN
# 10  6203.23      1.5  0.562369  1.65786   NaN
# 11  6644.92      1.5      0.99  1.67663   NaN
# ==========init params=========
# m0 =   1.6226
# b =  12.1864
# gamma_k =   0.1347
# sigma =   0.6207
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.6314
# b =  12.1235
# gamma_k =   0.1477
# sigma =   0.6492
#
#
#          LL        b         g        m sigma
# 0   5601.97  12.1235  0.568835  1.59764   NaN
# 1    5615.8  8.58235  0.568835  1.58884   NaN
# 2   5618.15  8.58235  0.147671  1.58124   NaN
# 3   5622.21  5.04118  0.147671  1.57146   NaN
# 4   5623.33  12.1235  0.147671  1.58344   NaN
# 5   5666.21  5.04118  0.568835  1.57152   NaN
# 6   5671.27  12.1235      0.99  1.58349   NaN
# 7   5715.94  8.58235      0.99  1.58003   NaN
# 8   5754.52      1.5  0.147671  1.55115   NaN
# 9   5860.07  5.04118      0.99  1.58712   NaN
# 10  6122.58      1.5  0.568835  1.59854   NaN
# 11  6607.12      1.5      0.99  1.62788   NaN
# ==========init params=========
# m0 =   1.5976
# b =  12.1235
# gamma_k =   0.5688
# sigma =   0.6492
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5958
# b =  23.8112
# gamma_k =   0.8180
# sigma =   0.5981
#
#
#          LL        b         g        m sigma
# 0   5563.53  16.3741  0.818024  1.52986   NaN
# 1   5563.93  16.3741  0.904012  1.53559   NaN
# 2   5568.55  8.93705  0.818024  1.52745   NaN
# 3   5569.83  23.8112  0.904012   1.5303   NaN
# 4   5573.06  23.8112  0.818024  1.52317   NaN
# 5   5575.69  23.8112      0.99  1.54029   NaN
# 6   5576.05  8.93705  0.904012  1.52799   NaN
# 7   5576.52  16.3741      0.99   1.5382   NaN
# 8   5598.07  8.93705      0.99   1.5301   NaN
# 9   6207.41      1.5  0.818024   1.5398   NaN
# 10  6305.89      1.5  0.904012  1.54536   NaN
# 11  6492.04      1.5      0.99  1.54936   NaN
# ==========init params=========
# m0 =   1.5299
# b =  16.3741
# gamma_k =   0.8180
# sigma =   0.5981
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5432
# b =  16.4677
# gamma_k =   0.7697
# sigma =   0.7072
#
#
#          LL        b         g        m sigma
# 0   5546.18  11.4785      0.99  1.51196   NaN
# 1    5547.4  11.4785  0.879832  1.50889   NaN
# 2   5548.87  6.48925  0.769665  1.50178   NaN
# 3   5550.67  6.48925  0.879832  1.50107   NaN
# 4   5553.23  16.4677      0.99  1.51187   NaN
# 5   5553.73  11.4785  0.769665  1.52031   NaN
# 6   5557.49  16.4677  0.879832  1.53978   NaN
# 7   5562.62  16.4677  0.769665   1.5544   NaN
# 8   5572.31  6.48925      0.99   1.5013   NaN
# 9   6153.66      1.5  0.769665  1.53199   NaN
# 10  6271.05      1.5  0.879832  1.54381   NaN
# 11  6513.63      1.5      0.99  1.55979   NaN
# ==========init params=========
# m0 =   1.5120
# b =  11.4785
# gamma_k =   0.9900
# sigma =   0.7072
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4927
# b =   8.9071
# gamma_k =   0.9228
# sigma =   0.6331
#
#
#          LL        b         g        m sigma
# 0   5536.76  6.43809  0.956394  1.45654   NaN
# 1   5536.88  6.43809      0.99  1.45485   NaN
# 2   5537.32  6.43809  0.922788  1.46356   NaN
# 3   5539.55  8.90713      0.99  1.47754   NaN
# 4   5539.97  8.90713  0.956394   1.4805   NaN
# 5   5540.67  8.90713  0.922788  1.47993   NaN
# 6   5554.27  3.96904  0.922788  1.44338   NaN
# 7    5559.3  3.96904  0.956394  1.44412   NaN
# 8   5573.57  3.96904      0.99   1.4453   NaN
# 9   6168.32      1.5  0.922788  1.48074   NaN
# 10  6230.85      1.5  0.956394  1.48519   NaN
# 11  6349.18      1.5      0.99  1.49134   NaN
# ==========init params=========
# m0 =   1.4565
# b =   6.4381
# gamma_k =   0.9564
# sigma =   0.6331
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4630
# b =   7.1777
# gamma_k =   0.9563
# sigma =   0.5530
#
#
#          LL        b         g        m sigma
# 0   5527.65  5.28511      0.99  1.42344   NaN
# 1   5528.02  5.28511  0.973149  1.42321   NaN
# 2   5528.67  5.28511  0.956298  1.42326   NaN
# 3   5534.14  7.17766      0.99  1.42952   NaN
# 4   5536.55  7.17766  0.973149  1.42932   NaN
# 5   5538.42  7.17766  0.956298  1.42922   NaN
# 6   5541.98  3.39255  0.956298  1.40236   NaN
# 7   5544.61  3.39255  0.973149  1.40242   NaN
# 8   5550.65  3.39255      0.99   1.4025   NaN
# 9   6087.55      1.5  0.956298  1.42136   NaN
# 10  6130.97      1.5  0.973149  1.42352   NaN
# 11  6204.58      1.5      0.99  1.42625   NaN
# ==========init params=========
# m0 =   1.4234
# b =   5.2851
# gamma_k =   0.9900
# sigma =   0.5530
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4395
# b =   6.0403
# gamma_k =   0.9646
# sigma =   0.6474
#
#
#          LL        b         g        m sigma
# 0   5520.87  4.52688      0.99   1.4082   NaN
# 1   5521.57  4.52688  0.977298  1.40823   NaN
# 2   5522.57  4.52688  0.964595  1.40835   NaN
# 3   5529.74  6.04033      0.99  1.41841   NaN
# 4   5532.68  6.04033  0.977298  1.41977   NaN
# 5   5533.89  6.04033  0.964595  1.44952   NaN
# 6    5539.5  3.01344  0.964595  1.38844   NaN
# 7   5542.33  3.01344  0.977298  1.38858   NaN
# 8   5547.82  3.01344      0.99  1.38899   NaN
# 9   6069.15      1.5  0.964595   1.4293   NaN
# 10  6105.86      1.5  0.977298  1.43248   NaN
# 11  6165.03      1.5      0.99  1.43702   NaN
# ==========init params=========
# m0 =   1.4082
# b =   4.5269
# gamma_k =   0.9900
# sigma =   0.6474
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4020
# b =   4.7140
# gamma_k =   0.9965
# sigma =   0.5987
#
#
#          LL        b         g        m sigma
# 0   5517.73  3.64269  0.996468  1.37526   NaN
# 1   5518.02  3.64269  0.993234  1.37556   NaN
# 2   5518.41  3.64269      0.99  1.37583   NaN
# 3    5526.7  4.71403      0.99  1.41507   NaN
# 4   5526.73  4.71403  0.993234  1.41399   NaN
# 5   5526.89  4.71403  0.996468  1.41134   NaN
# 6   5544.78  2.57134      0.99  1.36002   NaN
# 7   5547.29  2.57134  0.993234  1.36019   NaN
# 8   5551.49  2.57134  0.996468  1.36053   NaN
# 9   6034.99      1.5      0.99  1.39413   NaN
# 10  6058.23      1.5  0.993234  1.39577   NaN
# 11  6093.83      1.5  0.996468  1.39808   NaN
# ==========init params=========
# m0 =   1.3753
# b =   3.6427
# gamma_k =   0.9965
# sigma =   0.5987
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.3736
# b =   3.8084
# gamma_k =   0.9993
# sigma =   0.5718

# %% [markdown]
# ## save params

# %%
import pickle
from datetime import date
# obj0, obj1, obj2 are created here...

data_name = 'GLD'
model_name = ''.join((date.today().strftime('%y%m%d'),"_"+ str(kbar)+ op_methods+ str(data_name) + '.pkl'))
# Saving the objects:
with open(model_name, 'wb') as f: 
    pickle.dump(result.params, f)
    print(model_name)
# Out:
# 180312_10slsqpGLD.pkl

# %% [markdown]
# ### load params

# %%
import pickle
# # Getting back the objects:
kbar = 10
with open('180225_10slsqpGLD.pkl', 'rb') as f:  # Python 3: open(..., 'rb')
    rez_2 = pickle.load(f)

# %%
rez = rez_2

# %% [markdown]
# ## get forecast params

# %%
predict_period = -1
pi_mat, A, sigma, s = MSM_likelihood_wantto_forecast(rez, kbar, data, predict_period)

# %% [markdown]
# ## forecast 1 day

# %%
len(data2)
# Out:
# 8056

# %%
len(data)
# Out:
# 11055

# %%
# df for OLS
starting_index = len(data)-len(df_reg)
predict_period = 30
from time import time

t1 = time()
Pdict = df()
Pdict["vol"] = []
df_reg["vol"] = 0.


vol = np.ones((predict_period,1))
vol = vol.astype(float)
for i in range(starting_index+1,len(pi_mat)-1):
    state_now = pi_mat[i , :]
    for t in range(0,predict_period):
        vol[t,0] = np.inner(np.matmul(state_now, np.linalg.matrix_power(A, t+1)),s[1,:])
    df_reg.loc[len(pi_mat)-i-2,"vol"] = sum(vol)
print("TIME : %2.5f" %(time() - t1)) 
#     Pdict.loc[i,"vol"] = sum(vol)
# Out:
# TIME : 6005.96716

# %% [markdown]
# ### save forcast data

# %%
name = 'GVZreg'+str(predict_period)
name_L = 'Output'.join((date.today().strftime('%y%m%d'),name+'.xlsx'))
writer = pd.ExcelWriter(name_L)
print(name_L)
df_reg.to_excel(writer, 'Sheet1')
writer.save()
# Out:
# 180312OutputGVZreg30.xlsx

# %% [markdown]
# ### load forecast data

# %%
filename = '180301OutputGVZreg30.xlsx' # '180310OutputGVZreg1.xlsx' 180312OutputGVZreg30.xlsx
xls = pd.ExcelFile(filename)
df_reg = pd.read_excel(xls)

# %% [markdown]
# ## Regression

# %%
df_reg
# Out:
#           Date    GVZ      GLD        vol
# 999 2014-03-03  17.05  1289.80   0.000000
# 998 2014-03-04  16.75  1283.79  20.653213
# 997 2014-03-05  16.58  1283.90  21.828884
# 996 2014-03-06  16.31  1293.36  22.538794
# 995 2014-03-07  15.82  1303.20  22.662567
# 994 2014-03-10  15.83  1296.68  22.200353
# 993 2014-03-11  16.14  1295.90  21.314360
# 992 2014-03-12  16.67  1291.55  21.432773
# 991 2014-03-13  17.30  1284.30  22.259553
# 990 2014-03-14  18.32  1299.62  21.597977
# 989 2014-03-17  17.87  1310.27  21.375178
# 988 2014-03-18  17.37  1308.04  20.591535
# 987 2014-03-19  17.59  1289.92  20.530782
# 986 2014-03-20  16.91  1289.30  21.382526
# 985 2014-03-21  16.43  1288.79  20.584387
# 984 2014-03-24  17.53  1295.83  21.070273
# 983 2014-03-25  17.16  1293.60  20.488228
# 982 2014-03-26  17.32  1305.95  20.007248
# 981 2014-03-27  17.60  1296.17  19.402126
# 980 2014-03-28  17.48  1293.46  19.176616
# 979 2014-03-31  17.37  1293.07  21.771447
# 978 2014-04-01  16.65  1294.37  22.976036
# 977 2014-04-02  16.19  1291.99  22.656066
# 976 2014-04-03  16.01  1294.02  22.089366
# 975 2014-04-04  15.81  1292.56  23.713477
# 974 2014-04-07  15.95  1292.75  24.038830
# 973 2014-04-08  15.99  1264.90  23.501492
# 972 2014-04-09  14.83  1258.14  24.496969
# 971 2014-04-10  15.06  1255.58  24.861914
# 970 2014-04-11  15.19  1249.73  25.504586
# ..         ...    ...      ...        ...
# 29  2018-01-05  11.26  1320.47  14.684019
# 28  2018-01-08  11.19  1312.78  15.287894
# 27  2018-01-09  10.79  1316.92  14.692398
# 26  2018-01-10  10.79  1322.37  14.154514
# 25  2018-01-11  10.96  1337.95  13.657480
# 24  2018-01-12  11.62  1340.06  13.489221
# 23  2018-01-16  12.09  1338.43  13.610928
# 22  2018-01-17  11.77  1327.15  13.287649
# 21  2018-01-18  12.26  1327.12  13.634161
# 20  2018-01-19  11.43  1331.85  13.219952
# 19  2018-01-22  11.66  1333.62  13.281896
# 18  2018-01-23  11.72  1341.18  12.997171
# 17  2018-01-24  13.38  1358.47  13.109094
# 16  2018-01-25  13.04  1348.01  13.651858
# 15  2018-01-26  12.98  1349.70  13.618689
# 14  2018-01-29  13.25  1340.31  14.476505
# 13  2018-01-30  13.86  1338.51  14.331959
# 12  2018-01-31  12.97  1345.15  13.833793
# 11  2018-02-01  12.32  1348.70  13.495176
# 10  2018-02-02  13.11  1332.90  14.624349
# 9   2018-02-05  14.35  1339.68  14.968217
# 8   2018-02-06  13.80  1324.10  15.075175
# 7   2018-02-07  13.62  1318.52  14.752783
# 6   2018-02-08  14.85  1318.77  15.344917
# 5   2018-02-09  14.93  1316.15  15.725086
# 4   2018-02-12  14.37  1322.76  15.560847
# 3   2018-02-13  14.07  1329.63  15.148705
# 2   2018-02-14  14.97  1350.67  18.804213
# 1   2018-02-15  15.03  1353.70  19.055630
# 0   2018-02-16  13.96  1347.10  18.289031
#
# [1000 rows x 4 columns]

# %%
df_reg
# Out:
#           Date    GVZ      GLD        vol
# 999 2014-03-03  17.05  1289.80   0.000000
# 998 2014-03-04  16.75  1283.79  20.653213
# 997 2014-03-05  16.58  1283.90  21.828884
# 996 2014-03-06  16.31  1293.36  22.538794
# 995 2014-03-07  15.82  1303.20  22.662567
# 994 2014-03-10  15.83  1296.68  22.200353
# 993 2014-03-11  16.14  1295.90  21.314360
# 992 2014-03-12  16.67  1291.55  21.432773
# 991 2014-03-13  17.30  1284.30  22.259553
# 990 2014-03-14  18.32  1299.62  21.597977
# 989 2014-03-17  17.87  1310.27  21.375178
# 988 2014-03-18  17.37  1308.04  20.591535
# 987 2014-03-19  17.59  1289.92  20.530782
# 986 2014-03-20  16.91  1289.30  21.382526
# 985 2014-03-21  16.43  1288.79  20.584387
# 984 2014-03-24  17.53  1295.83  21.070273
# 983 2014-03-25  17.16  1293.60  20.488228
# 982 2014-03-26  17.32  1305.95  20.007248
# 981 2014-03-27  17.60  1296.17  19.402126
# 980 2014-03-28  17.48  1293.46  19.176616
# 979 2014-03-31  17.37  1293.07  21.771447
# 978 2014-04-01  16.65  1294.37  22.976036
# 977 2014-04-02  16.19  1291.99  22.656066
# 976 2014-04-03  16.01  1294.02  22.089366
# 975 2014-04-04  15.81  1292.56  23.713477
# 974 2014-04-07  15.95  1292.75  24.038830
# 973 2014-04-08  15.99  1264.90  23.501492
# 972 2014-04-09  14.83  1258.14  24.496969
# 971 2014-04-10  15.06  1255.58  24.861914
# 970 2014-04-11  15.19  1249.73  25.504586
# ..         ...    ...      ...        ...
# 29  2018-01-05  11.26  1320.47  14.684019
# 28  2018-01-08  11.19  1312.78  15.287894
# 27  2018-01-09  10.79  1316.92  14.692398
# 26  2018-01-10  10.79  1322.37  14.154514
# 25  2018-01-11  10.96  1337.95  13.657480
# 24  2018-01-12  11.62  1340.06  13.489221
# 23  2018-01-16  12.09  1338.43  13.610928
# 22  2018-01-17  11.77  1327.15  13.287649
# 21  2018-01-18  12.26  1327.12  13.634161
# 20  2018-01-19  11.43  1331.85  13.219952
# 19  2018-01-22  11.66  1333.62  13.281896
# 18  2018-01-23  11.72  1341.18  12.997171
# 17  2018-01-24  13.38  1358.47  13.109094
# 16  2018-01-25  13.04  1348.01  13.651858
# 15  2018-01-26  12.98  1349.70  13.618689
# 14  2018-01-29  13.25  1340.31  14.476505
# 13  2018-01-30  13.86  1338.51  14.331959
# 12  2018-01-31  12.97  1345.15  13.833793
# 11  2018-02-01  12.32  1348.70  13.495176
# 10  2018-02-02  13.11  1332.90  14.624349
# 9   2018-02-05  14.35  1339.68  14.968217
# 8   2018-02-06  13.80  1324.10  15.075175
# 7   2018-02-07  13.62  1318.52  14.752783
# 6   2018-02-08  14.85  1318.77  15.344917
# 5   2018-02-09  14.93  1316.15  15.725086
# 4   2018-02-12  14.37  1322.76  15.560847
# 3   2018-02-13  14.07  1329.63  15.148705
# 2   2018-02-14  14.97  1350.67  18.804213
# 1   2018-02-15  15.03  1353.70  19.055630
# 0   2018-02-16  13.96  1347.10  18.289031
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### y= mx +c ; y as GVZ

# %%
import statsmodels.api as sm

# print('dataset = %1.0f' %row)

for ele in rez:
    print(ele,' = %8.4f'  %rez[ele].value)

x = df_reg.loc[:,'vol'].values.reshape(len(df_reg),1)
y = df_reg['GVZ']

x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# print("MODEL MSE",est2.mse_model)
print("MODEL MSE",est2.mse_resid)
print("MODEL TSE",est2.mse_total)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# m0  =   1.3736
# b  =   3.8084
# gamma_k  =   0.9993
# sigma  =   0.5718
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GVZ   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     6.259
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):             0.0125
# Time:                        19:24:29   Log-Likelihood:                -2547.5
# No. Observations:                1000   AIC:                             5099.
# Df Residuals:                     998   BIC:                             5109.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         14.8274      0.406     36.533      0.000      14.031      15.624
# x1             0.0655      0.026      2.502      0.013       0.014       0.117
# ==============================================================================
# Omnibus:                       30.579   Durbin-Watson:                   0.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.881
# Skew:                           0.444   Prob(JB):                     7.24e-08
# Kurtosis:                       2.998   Cond. No.                         64.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MODEL MSE 9.57515990692
# MODEL TSE 9.62556641401

# %% [markdown]
# ### y= mx ; y as GVZ

# %%
est = sm.OLS(y, x)
est2 = est.fit()
print(est2.summary())
print("MODEL MSE",est2.mse_resid)
print("MODEL TSE",est2.mse_total)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GVZ   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                 1.061e+04
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        19:24:29   Log-Likelihood:                -2972.0
# No. Observations:                1000   AIC:                             5946.
# Df Residuals:                     999   BIC:                             5951.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.9938      0.010    103.029      0.000       0.975       1.013
# ==============================================================================
# Omnibus:                        4.501   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.105   Jarque-Bera (JB):                4.577
# Skew:                          -0.160   Prob(JB):                        0.101
# Kurtosis:                       2.913   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MODEL MSE 22.3577487322
# MODEL TSE 259.6612172

# %% [markdown]
# ### change y to realized vol

# %%
y = (np.log(1+df_reg["GLD"].pct_change().dropna())*100)**2

# %%
plt.hist(np.sqrt(y))
plt.show()

# %%
x = df_reg.loc[2443:,'vol'].values.reshape(len(df_reg)-1,1)

x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# print("MODEL MSE",est2.mse_model)
print("MODEL MSE",est2.mse_resid)
print("MODEL TSE",est2.mse_total)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GLD   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     365.2
# Date:                Mon, 05 Mar 2018   Prob (F-statistic):           5.48e-76
# Time:                        13:48:45   Log-Likelihood:                -6330.3
# No. Observations:                2444   AIC:                         1.266e+04
# Df Residuals:                    2442   BIC:                         1.268e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.5028      0.255    -13.750      0.000      -4.002      -3.003
# x1             0.3497      0.018     19.111      0.000       0.314       0.386
# ==============================================================================
# Omnibus:                     4372.082   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7194174.381
# Skew:                          12.469   Prob(JB):                         0.00
# Kurtosis:                     267.622   Cond. No.                         54.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MODEL MSE 10.4145731312
# MODEL TSE 11.9673073586

# %% [markdown]
# ### reg y:realize x:1dayvol

# %%
df_reg
# Out:
#            Date    GVZ      GLD       vol
# 2444 2008-06-03  22.89   859.75  0.000000
# 2443 2008-06-04  22.69   887.10  0.296299
# 2442 2008-06-05  22.78   907.62  0.343200
# 2441 2008-06-06  23.60   913.25  0.383804
# 2440 2008-06-09  24.47   849.85  0.352073
# 2439 2008-06-10  25.39   833.05  0.370142
# 2438 2008-06-11  25.36   836.70  0.349232
# 2437 2008-06-12  25.04   846.90  0.427358
# 2436 2008-06-13  24.94   804.60  0.444245
# 2435 2008-06-16  24.98   783.35  0.409408
# 2434 2008-06-17  24.45   796.90  0.388900
# 2433 2008-06-18  23.93   771.65  0.375027
# 2432 2008-06-19  24.33   730.45  0.354743
# 2431 2008-06-20  26.22   721.45  0.330844
# 2430 2008-06-23  27.18   734.75  0.539446
# 2429 2008-06-24  26.79   730.80  0.644619
# 2428 2008-06-25  26.78   746.95  0.585032
# 2427 2008-06-26  27.33   754.95  0.560847
# 2426 2008-06-27  26.47   738.13  0.505976
# 2425 2008-06-30  26.92   724.55  0.500445
# 2424 2008-07-01  27.64   723.45  0.456354
# 2423 2008-07-02  27.54   763.25  0.416762
# 2422 2008-07-03  26.85   740.35  0.393103
# 2421 2008-07-07  26.59   732.85  0.482327
# 2420 2008-07-08  26.12   736.65  0.438724
# 2419 2008-07-09  26.09   746.20  0.448049
# 2418 2008-07-10  26.79   731.70  0.440893
# 2417 2008-07-11  33.32   712.30  0.403782
# 2416 2008-07-14  31.09   736.50  0.384061
# 2415 2008-07-15  30.40   742.10  0.402589
# ...         ...    ...      ...       ...
# 29   2018-01-05  11.26  1320.47  0.564980
# 28   2018-01-08  11.19  1312.78  0.591878
# 27   2018-01-09  10.79  1316.92  0.524746
# 26   2018-01-10  10.79  1322.37  0.477530
# 25   2018-01-11  10.96  1337.95  0.440276
# 24   2018-01-12  11.62  1340.06  0.431038
# 23   2018-01-16  12.09  1338.43  0.443456
# 22   2018-01-17  11.77  1327.15  0.418883
# 21   2018-01-18  12.26  1327.12  0.449738
# 20   2018-01-19  11.43  1331.85  0.415733
# 19   2018-01-22  11.66  1333.62  0.423642
# 18   2018-01-23  11.72  1341.18  0.402601
# 17   2018-01-24  13.38  1358.47  0.414575
# 16   2018-01-25  13.04  1348.01  0.460085
# 15   2018-01-26  12.98  1349.70  0.451996
# 14   2018-01-29  13.25  1340.31  0.522790
# 13   2018-01-30  13.86  1338.51  0.498866
# 12   2018-01-31  12.97  1345.15  0.453880
# 11   2018-02-01  12.32  1348.70  0.428947
# 10   2018-02-02  13.11  1332.90  0.526547
# 9    2018-02-05  14.35  1339.68  0.544301
# 8    2018-02-06  13.80  1324.10  0.543444
# 7    2018-02-07  13.62  1318.52  0.509673
# 6    2018-02-08  14.85  1318.77  0.558486
# 5    2018-02-09  14.93  1316.15  0.581490
# 4    2018-02-12  14.37  1322.76  0.557831
# 3    2018-02-13  14.07  1329.63  0.520184
# 2    2018-02-14  14.97  1350.67  0.811014
# 1    2018-02-15  15.03  1353.70  0.789644
# 0    2018-02-16  13.96  1347.10  0.698909
#
# [2445 rows x 4 columns]

# %%
y = (np.log(1+df_reg["GLD"].pct_change().dropna())*100)**2

# %%
x = df_reg.loc[2443:,'vol'].values.reshape(len(df_reg)-1,1)

x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# print("MODEL MSE",est2.mse_model)
print("MODEL MSE",est2.mse_resid)
print("MODEL TSE",est2.mse_total)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GLD   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.176
# Date:                Mon, 05 Mar 2018   Prob (F-statistic):              0.278
# Time:                        14:09:21   Log-Likelihood:                -6500.0
# No. Observations:                2444   AIC:                         1.300e+04
# Df Residuals:                    2442   BIC:                         1.302e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0216      0.182      5.624      0.000       0.665       1.378
# x1             0.2870      0.265      1.084      0.278      -0.232       0.806
# ==============================================================================
# Omnibus:                     4313.697   Durbin-Watson:                   1.712
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5793188.232
# Skew:                          12.200   Prob(JB):                         0.00
# Kurtosis:                     240.263   Cond. No.                         5.38
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MODEL MSE 11.9664458034
# MODEL TSE 11.9673073586

# %% [markdown]
# > The result told me that I can't use MSM with Gold price processes.
#
# REALLY?

# %%
Data
# Out:
#            Dates     GLD    GVZ      SPX    VIX      USO    OVX
# 0     1968-03-14     NaN    NaN    88.32    NaN      NaN    NaN
# 1     1968-03-15     NaN    NaN    89.10    NaN      NaN    NaN
# 2     1968-03-18     NaN    NaN    89.59    NaN      NaN    NaN
# 3     1968-03-19     NaN    NaN    88.99    NaN      NaN    NaN
# 4     1968-03-20     NaN    NaN    88.98    NaN      NaN    NaN
# 5     1968-03-21     NaN    NaN    88.33    NaN      NaN    NaN
# 6     1968-03-22     NaN    NaN    88.42    NaN      NaN    NaN
# 7     1968-03-25     NaN    NaN    88.33    NaN      NaN    NaN
# 8     1968-03-26     NaN    NaN    88.93    NaN      NaN    NaN
# 9     1968-03-27     NaN    NaN    89.66    NaN      NaN    NaN
# 10    1968-03-28     NaN    NaN    89.57    NaN      NaN    NaN
# 11    1968-03-29     NaN    NaN    90.20    NaN      NaN    NaN
# 12    1968-04-01     NaN    NaN    92.48    NaN      NaN    NaN
# 13    1968-04-02     NaN    NaN    92.64    NaN      NaN    NaN
# 14    1968-04-03     NaN    NaN    93.47    NaN      NaN    NaN
# 15    1968-04-04     NaN    NaN    93.84    NaN      NaN    NaN
# 16    1968-04-05     NaN    NaN    93.29    NaN      NaN    NaN
# 17    1968-04-08     NaN    NaN    94.95    NaN      NaN    NaN
# 18    1968-04-09     NaN    NaN    94.95    NaN      NaN    NaN
# 19    1968-04-10     NaN    NaN    95.67    NaN      NaN    NaN
# 20    1968-04-11     NaN    NaN    96.53    NaN      NaN    NaN
# 21    1968-04-12     NaN    NaN    96.53    NaN      NaN    NaN
# 22    1968-04-15     NaN    NaN    96.59    NaN      NaN    NaN
# 23    1968-04-16     NaN    NaN    96.62    NaN      NaN    NaN
# 24    1968-04-17     NaN    NaN    96.81    NaN      NaN    NaN
# 25    1968-04-18     NaN    NaN    97.08    NaN      NaN    NaN
# 26    1968-04-19     NaN    NaN    95.85    NaN      NaN    NaN
# 27    1968-04-22     NaN    NaN    95.32    NaN      NaN    NaN
# 28    1968-04-23     NaN    NaN    96.48    NaN      NaN    NaN
# 29    1968-04-24     NaN    NaN    96.62    NaN      NaN    NaN
# ...          ...     ...    ...      ...    ...      ...    ...
# 13014 2018-01-31  127.65  12.97  2823.81  13.54  12.9800  22.23
# 13015 2018-02-01  128.07  12.32  2821.98  13.47  13.2400  22.24
# 13016 2018-02-02  126.39  13.11  2762.13  17.31  13.0400  23.80
# 13017 2018-02-05  126.71  14.35  2648.94  37.32  12.7700  25.91
# 13018 2018-02-06  125.38  13.80  2695.14  29.98  12.7000  26.59
# 13019 2018-02-07  124.79  13.62  2681.66  27.73  12.3700  26.79
# 13020 2018-02-08  124.98  14.85  2581.00  33.46  12.0900  29.50
# 13021 2018-02-09  124.77  14.93  2619.55  29.06  11.8600  29.85
# 13022 2018-02-12  125.37  14.37  2656.00  25.61  11.8900  29.42
# 13023 2018-02-13  126.08  14.07  2662.94  24.97  11.8700  30.39
# 13024 2018-02-14  128.23  14.97  2698.63  19.26  12.1800  27.73
# 13025 2018-02-15  128.38  15.03  2731.20  19.13  12.3300  27.57
# 13026 2018-02-16  127.96  13.96  2732.22  19.46  12.3800  26.97
# 13027 2018-02-19  127.96  13.96  2732.22  19.46  12.3800  26.97
# 13028 2018-02-20  126.24  14.08  2716.26  20.60  12.3900  27.58
# 13029 2018-02-21  125.66  13.83  2701.33  20.02  12.2900  26.93
# 13030 2018-02-22  126.30  13.47  2703.96  18.72  12.5900  24.98
# 13031 2018-02-23  126.14  11.97  2747.30  16.49  12.7700  24.37
# 13032 2018-02-26  126.45  11.89  2779.60  15.80  12.8600  24.36
# 13033 2018-02-27  125.13  11.76  2744.28  18.59  12.6500  25.29
# 13034 2018-02-28  125.00  11.74  2713.83  19.85  12.3700  26.92
# 13035 2018-03-01  124.72  12.07  2677.67  22.47  12.3500  26.98
# 13036 2018-03-02  125.39  11.97  2691.25  19.59  12.3700  26.15
# 13037 2018-03-05  125.18  11.89  2720.94  18.73  12.5900  26.30
# 13038 2018-03-06  126.53  12.33  2728.12  18.36  12.5700  25.55
# 13039 2018-03-07  125.72  12.37  2726.80  17.76  12.3500  26.94
# 13040 2018-03-08  125.42  11.57  2738.97  16.54  12.1500  26.16
# 13041 2018-03-09  125.54  10.94  2786.57  14.64  12.4700  26.23
# 13042 2018-03-12  125.54  11.01  2783.02  15.78  12.3700  24.02
# 13043 2018-03-13  125.73  10.54  2795.08  15.55  12.3226  25.64
#
# [13044 rows x 7 columns]

# %% [markdown]
# 13/03/2018
#
#
# # IMPORT NEW DATA

# %% [markdown]
# ## input

# %% [markdown]
# ### read data

# %%
Data = pd.read_excel('all_3_data2.xlsx','Sheet2')

# %%
Data
# Out:
#            Dates    GOLDS    GVZ      SPX    VIX    CL1    OVX
# 0     1974-12-31   183.85    NaN    67.65    NaN    NaN    NaN
# 1     1975-01-01   183.85    NaN    66.91    NaN    NaN    NaN
# 2     1975-01-02   175.00    NaN    65.96    NaN    NaN    NaN
# 3     1975-01-03   174.00    NaN    66.88    NaN    NaN    NaN
# 4     1975-01-06   173.50    NaN    66.88    NaN    NaN    NaN
# 5     1975-01-07   169.50    NaN    67.44    NaN    NaN    NaN
# 6     1975-01-08   180.00    NaN    67.14    NaN    NaN    NaN
# 7     1975-01-09   179.00    NaN    67.16    NaN    NaN    NaN
# 8     1975-01-10   177.25    NaN    68.56    NaN    NaN    NaN
# 9     1975-01-13   180.25    NaN    68.56    NaN    NaN    NaN
# 10    1975-01-14   177.10    NaN    70.23    NaN    NaN    NaN
# 11    1975-01-15   178.25    NaN    70.71    NaN    NaN    NaN
# 12    1975-01-16   176.00    NaN    71.07    NaN    NaN    NaN
# 13    1975-01-17   178.75    NaN    71.02    NaN    NaN    NaN
# 14    1975-01-20   175.00    NaN    70.04    NaN    NaN    NaN
# 15    1975-01-21   175.75    NaN    71.17    NaN    NaN    NaN
# 16    1975-01-22   175.50    NaN    72.61    NaN    NaN    NaN
# 17    1975-01-23   174.00    NaN    72.31    NaN    NaN    NaN
# 18    1975-01-24   177.50    NaN    71.68    NaN    NaN    NaN
# 19    1975-01-27   179.00    NaN    72.14    NaN    NaN    NaN
# 20    1975-01-28   176.50    NaN    72.05    NaN    NaN    NaN
# 21    1975-01-29   178.00    NaN    70.96    NaN    NaN    NaN
# 22    1975-01-30   177.25    NaN    71.08    NaN    NaN    NaN
# 23    1975-01-31   175.80    NaN    70.70    NaN    NaN    NaN
# 24    1975-02-03   176.25    NaN    71.74    NaN    NaN    NaN
# 25    1975-02-04   174.25    NaN    72.07    NaN    NaN    NaN
# 26    1975-02-05   175.00    NaN    72.98    NaN    NaN    NaN
# 27    1975-02-06   173.40    NaN    75.37    NaN    NaN    NaN
# 28    1975-02-07   174.50    NaN    76.03    NaN    NaN    NaN
# 29    1975-02-10   174.00    NaN    77.26    NaN    NaN    NaN
# ...          ...      ...    ...      ...    ...    ...    ...
# 11249 2018-02-12  1322.76  12.97  2823.81  13.54  59.29  22.23
# 11250 2018-02-13  1329.63  12.32  2821.98  13.47  59.19  22.24
# 11251 2018-02-14  1350.67  13.11  2762.13  17.31  60.60  23.80
# 11252 2018-02-15  1353.70  14.35  2648.94  37.32  61.34  25.91
# 11253 2018-02-16  1347.10  13.80  2695.14  29.98  61.68  26.59
# 11254 2018-02-19  1346.59  13.62  2681.66  27.73  61.68  26.79
# 11255 2018-02-20  1329.15  14.85  2581.00  33.46  61.90  29.50
# 11256 2018-02-21  1324.53  14.93  2619.55  29.06  61.68  29.85
# 11257 2018-02-22  1332.20  14.37  2656.00  25.61  62.77  29.42
# 11258 2018-02-23  1328.75  14.07  2662.94  24.97  63.55  30.39
# 11259 2018-02-26  1333.47  14.97  2698.63  19.26  63.91  27.73
# 11260 2018-02-27  1318.30  15.03  2731.20  19.13  63.01  27.57
# 11261 2018-02-28  1318.38  13.96  2732.22  19.46  61.64  26.97
# 11262 2018-03-01  1316.93  13.96  2732.22  19.46  60.99  26.97
# 11263 2018-03-02  1322.75  14.08  2716.26  20.60  61.25  27.58
# 11264 2018-03-05  1320.15  13.83  2701.33  20.02  62.57  26.93
# 11265 2018-03-06  1334.65  13.47  2703.96  18.72  62.60  24.98
# 11266 2018-03-07  1325.52  11.97  2747.30  16.49  61.15  24.37
# 11267 2018-03-08  1321.97  11.89  2779.60  15.80  60.12  24.36
# 11268 2018-03-09  1323.30  11.76  2744.28  18.59  62.04  25.29
# 11269 2018-03-12  1323.05  11.74  2713.83  19.85  61.36  26.92
# 11270 2018-03-13  1326.45  12.07  2677.67  22.47  60.71  26.98
# 11271 2018-03-14  1324.70  11.97  2691.25  19.59  60.96  26.15
# 11272 2018-03-15  1316.29  11.89  2720.94  18.73  61.19  26.30
# 11273 2018-03-16  1314.35  12.33  2728.12  18.36  62.34  25.55
# 11274 2018-03-19  1316.85  12.37  2726.80  17.76  62.06  26.94
# 11275 2018-03-20  1311.30  11.57  2738.97  16.54  63.40  26.16
# 11276 2018-03-21  1332.45  10.94  2786.57  14.64  65.17  26.23
# 11277 2018-03-22  1329.02  11.01  2783.02  15.78  64.30  24.02
# 11278 2018-03-23  1347.25  10.54  2795.08  15.55  65.88  25.64
#
# [11279 rows x 7 columns]

# %% [markdown]
# ### dynamic execution of Python code.

# %%
asset = ('GOLDS', 'GVZ', 'SPX', 'VIX', 'CL1', 'OVX')#('GLD', 'GVZ', 'SPX', 'VIX', 'USO', 'OVX')
for i in range(0,len(asset)):
    exec( eval("asset["+str(i)+"]") +"= Data.loc[:,('Dates',"+"asset["+str(i)+"])]" )
    exec( eval("asset["+str(i)+"]") +"_r=100*np.log(1+"+ str(eval("asset["+str(i)+"]")+".iloc[:,1]")+".pct_change().dropna())" )
    exec( eval("asset["+str(i)+"]") +"="+ eval("asset["+str(i)+"]")+".dropna()" )

# %%
print("GOLDS len : " + str(len(GOLDS)) +'\n' +
      "GVZ   len : " + str(len(GVZ)) +'\n' +
      "SPX   len : " + str(len(SPX)) +'\n' +
      "VIX   len : " + str(len(VIX)) +'\n' +
      "CL1   len : " + str(len(CL1)) +'\n' +
      "OVX   len : " + str(len(OVX)) +'\n' )
# Out:
# GOLDS len : 11279
# GVZ   len : 2551
# SPX   len : 11279
# VIX   len : 7356
# CL1   len : 9128
# OVX   len : 2829

# %% [markdown]
# ### plot

# %%
for i in (0,2,4):
    fig,ax1 = plt.subplots()
    eval("ax1.plot("+eval('''asset['''+str(i)+''']''')+".loc[:,'Dates'],"+eval('''asset['''+str(i)+''']''')+".iloc[:,1],'b-')")
    ax2 = ax1.twinx()
    eval("ax2.plot("+eval('''asset['''+str(i)+''']''')+".iloc[1:,0],"+eval('''asset['''+str(i)+''']''')+"_r**2,color = 'tab:red', alpha = 0.5)")
    plt.title(eval('''asset['''+str(i)+''']''')+' data')


# data = GLD_r[::-1]
# data = data.reset_index(drop = True)
plt.show()

# %% [markdown]
# ## Fit data

# %%
for i in (0,2,4):
    name = eval('''asset['''+str(i)+''']''')
    exec( "data =" + eval('''asset['''+str(i)+''']''')+"_r" )
    distribution = "Normal"
    dof = 1 # for Chi**2 only
    send_out = "vol"
    
    output = df()
    output["m0"] = []
    output["b"] = []
    output["gamma_k"]=[]
    output["sigma"] = []
    output["LL"] = []
    result = []

    startingvals = []#[1.2, 1.2, 0.5 , 1.2 ]
    LB = [1, 1, 0.001, 0.0001]
    UB = [1.99, 50, 0.99999, 50]
    
    op_methods = 'slsqp'
    data2 = data

    for i in range(0,10):
        kbar = i+1
        if kbar >1 and bool(result):
            startingvals = [result.params['m0'].value,result.params['b'].value,
                            result.params['gamma_k'].value,result.params['sigma'].value]
        result = MSM_fitdata(data, kbar, LB, UB, op_methods, startingvals, distribution, dof, send_out)
         
        re2 = MSM_likelihood_new(result.params['m0'].value, result.params['b'].value,
                                 result.params['gamma_k'].value, result.params['sigma'].value, kbar, data2,
                                 distribution, dof, send_out)
        output.loc[i,"LL"] = re2
        for element in result.params:
            output.loc[i,element] = result.params[element].value
        
    writer = pd.ExcelWriter('Output'.join((date.today().strftime('%y%m%d'),op_methods+name+'varyk.xlsx')))
    output.to_excel(writer, 'Sheet1')
    writer.save()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-384325433311> in <module>()
#      26             startingvals = [result.params['m0'].value,result.params['b'].value,
#      27                             result.params['gamma_k'].value,result.params['sigma'].value]
# ---> 28         result = MSM_fitdata(data, kbar, LB, UB, op_methods, startingvals, distribution, dof, send_out)
#      29
#      30         re2 = MSM_likelihood_new(result.params['m0'].value, result.params['b'].value,
#
# <ipython-input-5-6186b9796ff1> in MSM_fitdata(data, kbar, LB, UB, op_methods, startingvals, distribution, dof, send_out)
#      13     """
#      14
# ---> 15     input_param, LLS = MSM_starting_values(data, startingvals, kbar, distribution, dof, send_out)
#      16         # print('LL = %8.4f' % LLS.loc[0, 'LL'])
#      17
#
# <ipython-input-3-ce2c8caa9304> in MSM_starting_values(data, startingvals, kbar, distribution, dof, send_out)
#      45             a_m0 = fminbound(MSM_likelihood_new, 1.2, 1.8,
#      46                              args=( b[i], g[j], sigma, kbar, data, distribution, dof, send_out),
# ---> 47                              xtol=1e-05, maxfun=500, full_output=True)  # , disp=3)
#      48             LL_storage.loc[len(LL_storage), 'LL'] = a_m0[1]
#      49             LL_storage.loc[len(LL_storage) - 1, 'b'] = b[i]
#
# /home/lawofearth/anaconda3/lib/python3.5/site-packages/scipy/optimize/optimize.py in fminbound(func, x1, x2, args, xtol, maxfun, full_output, disp)
#    1617                'disp': disp}
#    1618
# -> 1619     res = _minimize_scalar_bounded(func, (x1, x2), args, **options)
#    1620     if full_output:
#    1621         return res['x'], res['fun'], res['status'], res['nfev']
#
# /home/lawofearth/anaconda3/lib/python3.5/site-packages/scipy/optimize/optimize.py in _minimize_scalar_bounded(func, bounds, args, xatol, maxiter, disp, **unknown_options)
#    1662     rat = e = 0.0
#    1663     x = xf
# -> 1664     fx = func(x, *args)
#    1665     num = 1
#    1666     fmin_data = (1, xf, fx)
#
# <ipython-input-4-0d8fab658a63> in MSM_likelihood_new(distribution, dof, send_out, *args)
#     136     if distribution == 'Normal':
#     137         w_t = np.matlib.repmat(data2, 1, k2)
# --> 138         w_t = np.divide(pa * np.e ** (-0.5 * np.power(np.divide(w_t, s), 2)), s)
#     139         w_t = w_t + 10 ** -16
#     140     elif distribution == 'ChiSq':
#
# KeyboardInterrupt:

# %% [markdown]
# # Forecast new 3

# %% [markdown]
# ## Train data

# %%
Data
# Out:
#            Dates     GLD    GVZ      SPX    VIX      USO    OVX
# 0     1968-03-14     NaN    NaN    88.32    NaN      NaN    NaN
# 1     1968-03-15     NaN    NaN    89.10    NaN      NaN    NaN
# 2     1968-03-18     NaN    NaN    89.59    NaN      NaN    NaN
# 3     1968-03-19     NaN    NaN    88.99    NaN      NaN    NaN
# 4     1968-03-20     NaN    NaN    88.98    NaN      NaN    NaN
# 5     1968-03-21     NaN    NaN    88.33    NaN      NaN    NaN
# 6     1968-03-22     NaN    NaN    88.42    NaN      NaN    NaN
# 7     1968-03-25     NaN    NaN    88.33    NaN      NaN    NaN
# 8     1968-03-26     NaN    NaN    88.93    NaN      NaN    NaN
# 9     1968-03-27     NaN    NaN    89.66    NaN      NaN    NaN
# 10    1968-03-28     NaN    NaN    89.57    NaN      NaN    NaN
# 11    1968-03-29     NaN    NaN    90.20    NaN      NaN    NaN
# 12    1968-04-01     NaN    NaN    92.48    NaN      NaN    NaN
# 13    1968-04-02     NaN    NaN    92.64    NaN      NaN    NaN
# 14    1968-04-03     NaN    NaN    93.47    NaN      NaN    NaN
# 15    1968-04-04     NaN    NaN    93.84    NaN      NaN    NaN
# 16    1968-04-05     NaN    NaN    93.29    NaN      NaN    NaN
# 17    1968-04-08     NaN    NaN    94.95    NaN      NaN    NaN
# 18    1968-04-09     NaN    NaN    94.95    NaN      NaN    NaN
# 19    1968-04-10     NaN    NaN    95.67    NaN      NaN    NaN
# 20    1968-04-11     NaN    NaN    96.53    NaN      NaN    NaN
# 21    1968-04-12     NaN    NaN    96.53    NaN      NaN    NaN
# 22    1968-04-15     NaN    NaN    96.59    NaN      NaN    NaN
# 23    1968-04-16     NaN    NaN    96.62    NaN      NaN    NaN
# 24    1968-04-17     NaN    NaN    96.81    NaN      NaN    NaN
# 25    1968-04-18     NaN    NaN    97.08    NaN      NaN    NaN
# 26    1968-04-19     NaN    NaN    95.85    NaN      NaN    NaN
# 27    1968-04-22     NaN    NaN    95.32    NaN      NaN    NaN
# 28    1968-04-23     NaN    NaN    96.48    NaN      NaN    NaN
# 29    1968-04-24     NaN    NaN    96.62    NaN      NaN    NaN
# ...          ...     ...    ...      ...    ...      ...    ...
# 13014 2018-01-31  127.65  12.97  2823.81  13.54  12.9800  22.23
# 13015 2018-02-01  128.07  12.32  2821.98  13.47  13.2400  22.24
# 13016 2018-02-02  126.39  13.11  2762.13  17.31  13.0400  23.80
# 13017 2018-02-05  126.71  14.35  2648.94  37.32  12.7700  25.91
# 13018 2018-02-06  125.38  13.80  2695.14  29.98  12.7000  26.59
# 13019 2018-02-07  124.79  13.62  2681.66  27.73  12.3700  26.79
# 13020 2018-02-08  124.98  14.85  2581.00  33.46  12.0900  29.50
# 13021 2018-02-09  124.77  14.93  2619.55  29.06  11.8600  29.85
# 13022 2018-02-12  125.37  14.37  2656.00  25.61  11.8900  29.42
# 13023 2018-02-13  126.08  14.07  2662.94  24.97  11.8700  30.39
# 13024 2018-02-14  128.23  14.97  2698.63  19.26  12.1800  27.73
# 13025 2018-02-15  128.38  15.03  2731.20  19.13  12.3300  27.57
# 13026 2018-02-16  127.96  13.96  2732.22  19.46  12.3800  26.97
# 13027 2018-02-19  127.96  13.96  2732.22  19.46  12.3800  26.97
# 13028 2018-02-20  126.24  14.08  2716.26  20.60  12.3900  27.58
# 13029 2018-02-21  125.66  13.83  2701.33  20.02  12.2900  26.93
# 13030 2018-02-22  126.30  13.47  2703.96  18.72  12.5900  24.98
# 13031 2018-02-23  126.14  11.97  2747.30  16.49  12.7700  24.37
# 13032 2018-02-26  126.45  11.89  2779.60  15.80  12.8600  24.36
# 13033 2018-02-27  125.13  11.76  2744.28  18.59  12.6500  25.29
# 13034 2018-02-28  125.00  11.74  2713.83  19.85  12.3700  26.92
# 13035 2018-03-01  124.72  12.07  2677.67  22.47  12.3500  26.98
# 13036 2018-03-02  125.39  11.97  2691.25  19.59  12.3700  26.15
# 13037 2018-03-05  125.18  11.89  2720.94  18.73  12.5900  26.30
# 13038 2018-03-06  126.53  12.33  2728.12  18.36  12.5700  25.55
# 13039 2018-03-07  125.72  12.37  2726.80  17.76  12.3500  26.94
# 13040 2018-03-08  125.42  11.57  2738.97  16.54  12.1500  26.16
# 13041 2018-03-09  125.54  10.94  2786.57  14.64  12.4700  26.23
# 13042 2018-03-12  125.54  11.01  2783.02  15.78  12.3700  24.02
# 13043 2018-03-13  125.73  10.54  2795.08  15.55  12.3226  25.64
#
# [13044 rows x 7 columns]

# %%
maxlen = 3000

# %%
distribution = "Normal"
dof = 1 # for Chi**2 only
send_out = "vol"
    
for j in (0,2,4):
    
    # this step use partial data
    

    name = eval('''asset['''+str(j)+''']''')
    exec( "data =" + eval('''asset['''+str(j)+''']''')+"_r" )
    exec( "data_y =" + eval('''asset['''+str(j+1)+''']''') )
    
    if len(data_y) > maxlen :
        data_y = data_y.iloc[-maxlen:,1]
    else :
        data_y = data_y.iloc[:,1]

    data = data.iloc[:len(data)-len(data_y)]
            
    output = df()
    output["m0"] = []
    output["b"] = []
    output["gamma_k"]=[]
    output["sigma"] = []
    output["LL"] = []
    result = []

    startingvals = []#[1.2, 1.2, 0.5 , 1.2 ]
    LB = [1, 1, 0.001, 0.0001]
    UB = [1.99, 50, 0.99999, 50]
    
    op_methods = 'slsqp'
    data2 = data

    for i in range(0,10):
        kbar = i+1
        if kbar >1 and bool(result):
            startingvals = [result.params['m0'].value,result.params['b'].value,
                            result.params['gamma_k'].value,result.params['sigma'].value]
        result = MSM_fitdata(data, kbar, LB, UB, op_methods, startingvals, distribution, dof, send_out)
         
        re2 = MSM_likelihood_new(result.params['m0'].value, result.params['b'].value,
                                 result.params['gamma_k'].value, result.params['sigma'].value, kbar, data2,
                                 distribution, dof, send_out)
        output.loc[i,"LL"] = re2
        for element in result.params:
            output.loc[i,element] = result.params[element].value
        
    # save for report with xls
    writer = pd.ExcelWriter('Output'.join((date.today().strftime('%y%m%d'),'_'+name+op_methods+'partial_4forecast_varyk.xlsx')))
    output.to_excel(writer, 'Sheet1')
    writer.save()
    
    # save for use with .pkl
    model_name = ''.join((date.today().strftime('%y%m%d'),"_"+str(name) + str(kbar)+ op_methods+str(maxlen)+  'partial_forecast.pkl'))
    # Saving the objects:
    with open(model_name, 'wb') as f: 
        pickle.dump(result.params, f)
        print(model_name)
# Out:
# 180324_GOLDS10slsqp3000partial_forecast.pkl
# 180324_SPX10slsqp3000partial_forecast.pkl
# 180324_CL110slsqp3000partial_forecast.pkl

# %% [markdown]
# ## chain forecast

# %% [markdown]
# ### param

# %%
op_methods = 'slsqp'
kbar = 10
LB = [1, 1, 0.001, 0.0001]
UB = [1.99, 50, 0.99999, 50]
send_out = 'forecast multistep'
predict_period = 30
startingvals = []

# %% [markdown]
# ###  MSM forecast

# %%
param_name = ('180324_GOLDS10slsqp3000partial_forecast.pkl',
              '180324_SPX10slsqp3000partial_forecast.pkl',
              '180324_CL110slsqp3000partial_forecast.pkl')

# %%
position = (0,2,4)
position_y = (1,3,5)

distribution = "Normal"
dof = 1 # for Chi**2 only
# distribution = distribution
# dof = dof

for j in range(2,3):
    
    # get many data
    name = eval('''asset['''+str(position[j])+''']''')
    exec( "data =" + eval('''asset['''+str(position[j])+''']''')+"_r" ) # if VIX selete _r
    exec( "data_y =" + eval('''asset['''+str(position_y[j])+''']''') )
    ele = param_name[j]
    
    if len(data_y) > maxlen :
        data_y = data_y.iloc[-maxlen:,1]
    else :
        data_y = data_y.iloc[:,1]
        
    data_test = data.iloc[len(data_y):len(data)]
    starting_index = len(data_test)
    
    # load
    with open(ele, 'rb') as f: 
        rez = pickle.load(f)
        
    
    # find latent state variable -> use all data
    pi_mat, A, sigma, s = MSM_likelihood_new(rez, kbar, data, predict_period, distribution = distribution, dof = dof, send_out = send_out)
    
    
    # forecast use test data
    
    # df_reg matrix
    df_reg = []
    df_reg = data_y.to_frame()
    df_reg[name] = data
    df_reg['Dates']=Data['Dates']
    df_reg['MSM'] = 0.
    df_reg = df_reg.reset_index(drop=True)
    
    t1 = time()
    s1 = s[0,:]
    pi_mat_cut = pi_mat[starting_index+1:,:]
    vol=0
    for t in range(0,predict_period):
        AA = np.linalg.matrix_power(A, t+1)
        new_pi_A = np.matmul(pi_mat_cut,AA)
        vol = vol + np.transpose(np.inner(new_pi_A,s1))
    df_reg.loc[:,"MSM"]=vol
    
# df_reg.loc[len(pi_mat)-i-2,"MSM"] = sum(vol)
    print("TIME : %2.5f" %(time() - t1)) 
    
    #save
    name_L = 'MSM_vol'.join((date.today().strftime('%y%m%d'),'_'+name+str(maxlen)+"_"+distribution+'('+str(dof)+')_predict=['+str(predict_period)+'].xlsx'))
    writer = pd.ExcelWriter(name_L)
    print(name_L)
    df_reg.to_excel(writer, 'Sheet1')
    writer.save()

# %% [markdown]
# ### Load forecast and do a reg

# %%
filename = ("180326MSM_vol_GOLDS3000_Normal(1)_predict=[30].xlsx",
            "180326MSM_vol_SPX3000_Normal(1)_predict=[30].xlsx",
            "180326MSM_vol_S3000_Normal(1)_predict=[30].xlsx")

# %%
position = (0,2,4)
position_y = (1,3,5)

for i in range(0,3):
    
    # import old data
    ele = param_name[i]
    with open(ele, 'rb') as f: 
        rez = pickle.load(f)
    
    # load
    xls = pd.ExcelFile(filename[i])
    df_reg = pd.read_excel(xls)
    
    # reg
    for ele in rez:
        print(ele,' = %8.4f'  %rez[ele].value)
    
    # y = mx+c
    x = df_reg.loc[:,'MSM'].values.reshape(len(df_reg),1)
    y = df_reg[eval('''asset['''+str(position[i]+1)+''']''')]

    x2 = sm.add_constant(x)
    est = sm.OLS(y, x2)
    est2 = est.fit()
    print(est2.summary())
    print("MODEL MSE",est2.mse_resid)
    print("MODEL TSE",est2.mse_total)
    
    #y=mx
    est = sm.OLS(y, x)
    est2 = est.fit()
    print(est2.summary())
    print("MODEL MSE",est2.mse_resid)
    print("MODEL TSE",est2.mse_total)
    
    #y=mx+c for realized data
    y = df_reg[eval('''asset['''+str(position[i])+''']''')]**2
    x2 = sm.add_constant(x)
    est = sm.OLS(y, x2)
    est2 = est.fit()
    print(est2.summary())
    print("MODEL MSE",est2.mse_resid)
    print("MODEL TSE",est2.mse_total)
    
    #y=mx for realized data
    y = df_reg[eval('''asset['''+str(position[i])+''']''')]**2
    est = sm.OLS(y, x)
    est2 = est.fit()
    print(est2.summary())
    print("MODEL MSE",est2.mse_resid)
    print("MODEL TSE",est2.mse_total)
# Out:
# m0  =   1.4223
# b  =   4.8628
# gamma_k  =   0.9987
# sigma  =   1.8485
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GVZ   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.244
# Method:                 Least Squares   F-statistic:                     824.4
# Date:                Mon, 26 Mar 2018   Prob (F-statistic):          2.49e-157
# Time:                        12:16:40   Log-Likelihood:                -8482.3
# No. Observations:                2551   AIC:                         1.697e+04
# Df Residuals:                    2549   BIC:                         1.698e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         34.3929      0.510     67.419      0.000      33.393      35.393
# x1            -0.4430      0.015    -28.713      0.000      -0.473      -0.413
# ==============================================================================
# Omnibus:                     1150.249   Durbin-Watson:                   0.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5990.515
# Skew:                           2.130   Prob(JB):                         0.00
# Kurtosis:                       9.182   Cond. No.                         127.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MODEL MSE 45.2904128392
# MODEL TSE 59.9152431511
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GVZ   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     6968.
# Date:                Mon, 26 Mar 2018   Prob (F-statistic):               0.00
# Time:                        12:16:40   Log-Likelihood:                -9787.9
# No. Observations:                2551   AIC:                         1.958e+04
# Df Residuals:                    2550   BIC:                         1.958e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.5610      0.007     83.473      0.000       0.548       0.574
# ==============================================================================
# Omnibus:                      295.254   Durbin-Watson:                   0.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              623.062
# Skew:                           0.710   Prob(JB):                    5.06e-136
# Kurtosis:                       4.960   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MODEL MSE 126.000982358
# MODEL TSE 470.109063034
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  GOLDS   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     28.37
# Date:                Mon, 26 Mar 2018   Prob (F-statistic):           1.09e-07
# Time:                        12:16:40   Log-Likelihood:                -7164.6
# No. Observations:                2551   AIC:                         1.433e+04
# Df Residuals:                    2549   BIC:                         1.434e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8552      0.304      9.382      0.000       2.258       3.452
# x1            -0.0490      0.009     -5.327      0.000      -0.067      -0.031
# ==============================================================================
# Omnibus:                     4833.962   Durbin-Watson:                   1.796
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9411179.039
# Skew:                          14.170   Prob(JB):                         0.00
# Kurtosis:                     299.206   Cond. No.                         127.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MODEL MSE 16.1186403801
# MODEL TSE 16.2916768343
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  GOLDS   R-squared:                       0.072
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     197.1
# Date:                Mon, 26 Mar 2018   Prob (F-statistic):           3.45e-43
# Time:                        12:16:40   Log-Likelihood:                -7207.9
# No. Observations:                2551   AIC:                         1.442e+04
# Df Residuals:                    2550   BIC:                         1.442e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0343      0.002     14.040      0.000       0.030       0.039
# ==============================================================================
# Omnibus:                     4762.046   Durbin-Watson:                   1.736
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8513369.486
# Skew:                          13.731   Prob(JB):                         0.00
# Kurtosis:                     284.674   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MODEL MSE 16.6686667675
# MODEL TSE 17.9501703662
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-93264c3f9731> in <module>()
#      10
#      11     # load
# ---> 12     xls = pd.ExcelFile(filename[i])
#      13     df_reg = pd.read_excel(xls)
#      14
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     255             self.book = xlrd.open_workbook(file_contents=data)
#     256         elif isinstance(io, compat.string_types):
# --> 257             self.book = xlrd.open_workbook(io)
#     258         else:
#     259             raise ValueError('Must explicitly set engine if not passing in'
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     393         peek = file_contents[:peeksz]
#     394     else:
# --> 395         with open(filename, "rb") as f:
#     396             peek = f.read(peeksz)
#     397     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: '180325MSM_vol_SPX3000_Normal(1)_predict=[30].xlsx'

# %%
eval('''asset['''+str(position[i]+1)+''']''')
# Out:
# 'OVX'

# %%
df_reg
# Out:
#        OVX       USO      Dates       MSM
# 0    16.72  0.377257 2014-05-14  1.541231
# 1    15.94 -0.377257 2014-05-15  1.575834
# 2    15.42  0.511648 2014-05-16  1.473177
# 3    15.90  0.402091 2014-05-19  1.455534
# 4    16.20  0.373832 2014-05-20  1.423355
# 5    16.38  1.218558 2014-05-21  1.470143
# 6    16.05  0.078958 2014-05-22  1.439653
# 7    15.89  0.446254 2014-05-23  1.487002
# 8    15.89  0.000000 2014-05-26  1.534654
# 9    16.10 -0.104822 2014-05-27  1.466268
# 10   16.02 -1.213415 2014-05-28  1.446289
# 11   15.55  0.608548 2014-05-29  1.481922
# 12   15.61 -0.608548 2014-05-30  1.481388
# 13   15.52 -0.398884 2014-06-02  1.375307
# 14   15.53  0.292670 2014-06-03  1.405161
# 15   15.41 -0.345975 2014-06-04  1.454551
# 16   15.14  0.106581 2014-06-05  1.504154
# 17   14.50  0.159659 2014-06-06  1.550051
# 18   14.67  1.504185 2014-06-09  1.566772
# 19   14.74  0.261575 2014-06-10  1.461551
# 20   14.67 -0.078401 2014-06-11  1.509919
# 21   19.17  2.146727 2014-06-12  1.558290
# 22   19.47  0.102302 2014-06-13  1.526168
# 23   19.52  0.127730 2014-06-16  1.455000
# 24   17.40 -0.460594 2014-06-17  1.333591
# 25   17.28  0.051282 2014-06-18  1.366399
# 26   18.05  0.307141 2014-06-19  1.296123
# 27   18.84  0.484386 2014-06-20  1.272219
# 28   18.05 -0.407748 2014-06-23  1.196047
# 29   17.93 -0.178914 2014-06-24  1.221549
# ..     ...       ...        ...       ...
# 970  22.23  0.618240 2018-01-31  0.780282
# 971  22.24  1.983284 2018-02-01  0.794236
# 972  23.80 -1.522099 2018-02-02  0.806005
# 973  25.91 -2.092289 2018-02-05  0.824817
# 974  26.59 -0.549668 2018-02-06  0.848771
# 975  26.79 -2.632781 2018-02-07  0.865207
# 976  29.50 -2.289552 2018-02-08  0.890981
# 977  29.85 -1.920727 2018-02-09  0.918410
# 978  29.42  0.252632 2018-02-12  0.753251
# 979  30.39 -0.168350 2018-02-13  0.772292
# 980  27.73  2.578105 2018-02-14  0.789482
# 981  27.57  1.224005 2018-02-15  0.704608
# 982  26.97  0.404695 2018-02-16  0.721682
# 983  26.97  0.000000 2018-02-19  0.739579
# 984  27.58  0.080743 2018-02-20  0.752780
# 985  26.93 -0.810377 2018-02-21  0.768054
# 986  24.98  2.411692 2018-02-22  0.780837
# 987  24.37  1.419582 2018-02-23  0.785176
# 988  24.36  0.702305 2018-02-26  0.789870
# 989  25.29 -1.646450 2018-02-27  0.743855
# 990  26.92 -2.238303 2018-02-28  0.762917
# 991  26.98 -0.161812 2018-03-01  0.783117
# 992  26.15  0.161812 2018-03-02  0.795405
# 993  26.30  1.762866 2018-03-05  0.817066
# 994  25.55 -0.158983 2018-03-06  0.773328
# 995  26.94 -1.765696 2018-03-07  0.788229
# 996  26.16 -1.632689 2018-03-08  0.802972
# 997  26.23  2.599659 2018-03-09  0.814059
# 998  24.02 -0.805157 2018-03-12  0.831300
# 999  25.64 -0.383921 2018-03-13  0.000000
#
# [1000 rows x 4 columns]

# %%
for j in (1,3,5):
    name = eval('''asset['''+str(j)+''']''')
    exec( "data =" + str(eval('''asset['''+str(j)+''']'''))+".iloc[:,1]" )
    distribution = "ChiSq"
    dof = 1 # for Chi**2 only
    send_out = "vol"
    
    output = df()
    output["m0"] = []
    output["b"] = []
    output["gamma_k"]=[]
    output["sigma"] = []
    output["LL"] = []
    result = []

    startingvals = []#[1.2, 1.2, 0.5 , 1.2 ]
    LB = [1, 1, 0.001, 0.0001]
    UB = [1.99, 50, 0.99999, 50]
    
    op_methods = 'slsqp'
    data2 = data

    for i in range(0,10):
        kbar = i+1
        if kbar >1 and bool(result):
            startingvals = [result.params['m0'].value,result.params['b'].value,
                            result.params['gamma_k'].value,result.params['sigma'].value]
        result = MSM_fitdata(data, kbar, LB, UB, op_methods, startingvals, distribution, dof, send_out)
         
        re2 = MSM_likelihood_new(result.params['m0'].value, result.params['b'].value,
                                 result.params['gamma_k'].value, result.params['sigma'].value, kbar, data2,
                                 distribution, dof, send_out)
        output.loc[i,"LL"] = re2
        for element in result.params:
            output.loc[i,element] = result.params[element].value
        
    writer = pd.ExcelWriter('Output'.join((date.today().strftime('%y%m%d'),'_'+name+'_'+distribution+'varyk.xlsx')))
    output.to_excel(writer, 'Sheet1')
    writer.save()
