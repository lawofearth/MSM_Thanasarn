# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame as df
from MSM_util import *
from lmfit import minimize, Minimizer, Parameters, Parameter, report_fit
import sys, scipy, numpy

# print(scipy.__version__, numpy.__version__, sys.version_info)

# %%
# Hyper parameters

# How much period taken into calculation and prediction
m = 20
# number of days prediction
RV = 22
# kbar
kbar = 5

xls_data = pd.read_excel('data_GVZ_GLD.xlsx')
date_GLD = xls_data.iloc[:,3]
GLD = xls_data.loc[:,'GLD']

GLD2 = GLD.shift(1)
GLD2[0] = GLD[0]
GLD_r = GLD/GLD2

GLD_d = GLD_r - np.mean(GLD_r)
plt.plot(date_GLD,GLD)
plt.title('de-mean data')
plt.plot(date_GLD,200*GLD_r)

data = GLD_d[::-1]


startingvals = [1.2, 1.2, 0.5 , 1.2 ]
LB = [1, 1, 0.001, 0.0001]
UB = [1.99, 50, 0.99999, 5]
op_methods = 'slsqp'



plt.show()

# %% [markdown]
# # Fit data

# %%
output =msm_fitseries(data, kbar, LB, UB, op_methods, startingvals, m, RV)
# Out:
# ==========init params=========
# m0 =   1.2000
# b =   1.2000
# gamma_k =   0.5000
# sigma =   1.2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-463aeb0e26ce> in <module>()
# ----> 1 output =msm_fitseries(data, kbar, LB, UB, op_methods, startingvals, m, RV)
#
# C:\Users\lawof\Documents\Fractals\Thanasarn_MSM\GIT_MSM\MSM_util.py in msm_fitseries(data, kbar, LB, UB, op_methods, startingvals, m, RV)
#     252     for i in range(0, m):
#     253         data2 = data[i:len(data) - m + i]
# --> 254         result = MSM_fitdata(data2, kbar, LB, UB, op_methods, startingvals)
#     255         re2 = MSM_likelihood_new(result.params, kbar, data2, RV)
#     256         output.loc[i, "RV"] = sum(re2) ** 2 * 100
#
# C:\Users\lawof\Documents\Fractals\Thanasarn_MSM\GIT_MSM\MSM_util.py in MSM_fitdata(data, kbar, LB, UB, op_methods, startingvals)
#     229
#     230     minner = Minimizer(MSM_likelihood_new, params, fcn_args=(kbar, data))
# --> 231     result = minner.minimize(method=op_methods)
#     232
#     233     print("\n\n ==========fitted results==========")
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(self, method, params, **kws)
#    1647                         val.lower().startswith(user_method)):
#    1648                     kwargs['method'] = val
# -> 1649         return function(**kwargs)
#    1650
#    1651
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\minimizer.py in scalar_minimize(self, method, params, **kws)
#     774             ret = differential_evolution(self.penalty, _bounds, **kwargs)
#     775         else:
# --> 776             ret = scipy_minimize(self.penalty, vars, **fmin_kws)
#     777
#     778         result.aborted = self._abort
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     456     elif meth == 'slsqp':
#     457         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 458                                constraints, callback=callback, **options)
#     459     elif meth == 'dogleg':
#     460         return _minimize_dogleg(fun, x0, args, jac, hess,
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     388             # Compute the derivatives of the objective function
#     389             # For some reason SLSQP wants g dimensioned to n+1
# --> 390             g = append(fprime(x),0.0)
#     391
#     392             # Compute the normals of the constraints
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\slsqp.py in approx_jacobian(x, func, epsilon, *args)
#      61     for i in range(len(x0)):
#      62         dx[i] = epsilon
# ---> 63         jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#      64         dx[i] = 0.0
#      65
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\minimizer.py in penalty(self, fvars)
#     544
#     545         """
# --> 546         r = self.__residual(fvars)
#     547         if isinstance(r, ndarray) and r.size > 1:
#     548             r = self.reduce_fcn(r)
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\minimizer.py in __residual(self, fvars, apply_bounds_transformation)
#     486         self.result.nfev += 1
#     487
# --> 488         out = self.userfcn(params, *self.userargs, **self.userkws)
#     489         out = _nan_policy(out, nan_policy=self.nan_policy)
#     490
#
# C:\Users\lawof\Documents\Fractals\Thanasarn_MSM\GIT_MSM\MSM_util.py in MSM_likelihood_new(*args)
#     174
#     175     for t in range(0, T):
# --> 176         piA = np.matmul(pi_mat[t, :], A)
#     177         C = np.multiply(w_t[t, :], piA)
#     178         ft = sum(C)
#
# KeyboardInterrupt:

# %% [markdown]
# ## plot

# %%
 msm_plot(xls_data["GVZ"], output, m)

# %% [markdown]
# ## Regression

# %%
datainreg = xls_data["GVZ"][::-1]
data_lastm = datainreg
data_lastm = data_lastm.iloc[-m:]

linreg(df(output['RV']), df(data_lastm))
# Out:
# Slope :  -0.000660505652855
# Intercept :  11.3649091073
# (-0.00066050565285520808, 11.364909107349215)

# %% [markdown]
# ## XLSX

# %%
from datetime import date
namew="RV22m10.xlsx"
writer = pd.ExcelWriter("".join((date.today().strftime('%y%m%d'),namew)))
print(writer.path)
output.to_excel(writer, 'Sheet2')
writer.save()
# Out:
# 180210RV22m10.xlsx
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-592f284a47a2> in <module>()
#       3 writer = pd.ExcelWriter("".join((date.today().strftime('%y%m%d'),namew)))
#       4 print(writer.path)
# ----> 5 output.to_excel(writer, 'Sheet2')
#       6 writer.save()
#
# NameError: name 'output' is not defined

# %% [markdown]
# ### load

# %%
xls_file = pd.ExcelFile('180209RV22m10.xlsx')
output = xls_file.parse('Sheet2')

# %% [markdown]
# # Average params

# %%
output2 = msm_averageparams(output, kbar, m, data, RV, LB , UB)

# %% [markdown]
# ## plot

# %%
 msm_plot(xls_data["GVZ"], output2, m)

# %% [markdown]
# ## Regression

# %%
datainreg = xls_data["GVZ"][::-1]
data_lastm = datainreg
data_lastm = data_lastm.iloc[-m:]

linreg(df(output2['RV']), df(data_lastm))
# Out:
# Slope :  -4.71686314987e+13
# Intercept :  5.04301310203e+14
# (-47168631498709.805, 504301310203267.0)
