# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame as df
from MSM_util import *
from lmfit import minimize, Minimizer, Parameters, Parameter, report_fit
import sys, scipy, numpy

# print(scipy.__version__, numpy.__version__, sys.version_info)

# %%
# Hyper parameters

# How much period taken into calculation and prediction
m = 20
# number of days prediction
RV = 22
# kbar
kbar = 3

xls_data = pd.read_excel('data_GVZ_GLD.xlsx')
date_GLD = xls_data.iloc[:,3]
GLD = xls_data.loc[:,'GLD']

GLD2 = GLD.shift(1)
GLD2[0] = GLD[0]
GLD_r = GLD/GLD2

GLD_d = GLD_r - np.mean(GLD_r)
plt.plot(date_GLD,GLD)
plt.title('de-mean data')
plt.plot(date_GLD,200*GLD_r)

data = GLD_d[::-1]


startingvals = []#[1.2, 1.2, 0.5 , 1.2 ]
LB = [1, 1, 0.001, 0.0001]
UB = [1.99, 50, 0.99999, 5]
op_methods = 'slsqp'



plt.show()

# %% [markdown]
# # Fit data

# %%
output =msm_fitseries(data, kbar, LB, UB, op_methods, startingvals, m, RV)
# Out:
# No starting values entered: Using grid-search
# LL = -7814.4308
# ==========init params=========
# m0 =   1.4291
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1934
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4663
# b =   5.7643
# gamma_k =   0.0823
# sigma =   0.2467
# LLs = -7837.9933
# AIC =  25.9335
# BIC =  17.9335
# No starting values entered: Using grid-search
# LL = -7815.3224
# ==========init params=========
# m0 =   1.4297
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1934
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4667
# b =   5.7280
# gamma_k =   0.0815
# sigma =   0.2468
# LLs = -7838.9657
# AIC =  25.9337
# BIC =  17.9337
# No starting values entered: Using grid-search
# LL = -7818.1649
# ==========init params=========
# m0 =   1.4302
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1932
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4678
# b =   5.8804
# gamma_k =   0.0841
# sigma =   0.2472
# LLs = -7841.5591
# AIC =  25.9344
# BIC =  17.9344
# No starting values entered: Using grid-search
# LL = -7818.9222
# ==========init params=========
# m0 =   1.4310
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1932
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4679
# b =   5.8027
# gamma_k =   0.0828
# sigma =   0.2470
# LLs = -7842.3806
# AIC =  25.9346
# BIC =  17.9346
# No starting values entered: Using grid-search
# LL = -7821.4257
# ==========init params=========
# m0 =   1.4320
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1931
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4697
# b =   5.9920
# gamma_k =   0.0860
# sigma =   0.2477
# LLs = -7844.6656
# AIC =  25.9352
# BIC =  17.9352
# No starting values entered: Using grid-search
# LL = -7820.2284
# ==========init params=========
# m0 =   1.4298
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1931
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4682
# b =   5.8999
# gamma_k =   0.0843
# sigma =   0.2476
# LLs = -7843.7237
# AIC =  25.9349
# BIC =  17.9349
# No starting values entered: Using grid-search
# LL = -7819.9275
# ==========init params=========
# m0 =   1.4294
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1931
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4686
# b =   6.0697
# gamma_k =   0.0875
# sigma =   0.2480
# LLs = -7843.3132
# AIC =  25.9348
# BIC =  17.9348
# No starting values entered: Using grid-search
# LL = -7820.5146
# ==========init params=========
# m0 =   1.4294
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1931
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4678
# b =   5.9149
# gamma_k =   0.0846
# sigma =   0.2477
# LLs = -7844.0598
# AIC =  25.9350
# BIC =  17.9350
# No starting values entered: Using grid-search
# LL = -7821.1650
# ==========init params=========
# m0 =   1.4294
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1930
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4682
# b =   5.9978
# gamma_k =   0.0860
# sigma =   0.2480
# LLs = -7844.6450
# AIC =  25.9352
# BIC =  17.9352
# No starting values entered: Using grid-search
# LL = -7822.0997
# ==========init params=========
# m0 =   1.4295
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1930
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4680
# b =   5.9305
# gamma_k =   0.0846
# sigma =   0.2479
# LLs = -7845.6700
# AIC =  25.9354
# BIC =  17.9354
# No starting values entered: Using grid-search
# LL = -7822.9539
# ==========init params=========
# m0 =   1.4296
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1929
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4680
# b =   5.8872
# gamma_k =   0.0837
# sigma =   0.2479
# LLs = -7846.6052
# AIC =  25.9357
# BIC =  17.9357
# No starting values entered: Using grid-search
# LL = -7824.1894
# ==========init params=========
# m0 =   1.4299
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1929
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4684
# b =   5.8728
# gamma_k =   0.0832
# sigma =   0.2480
# LLs = -7847.8832
# AIC =  25.9360
# BIC =  17.9360
# No starting values entered: Using grid-search
# LL = -7824.6492
# ==========init params=========
# m0 =   1.4298
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1929
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4683
# b =   5.8293
# gamma_k =   0.0824
# sigma =   0.2480
# LLs = -7848.4391
# AIC =  25.9361
# BIC =  17.9361
# No starting values entered: Using grid-search
# LL = -7824.8517
# ==========init params=========
# m0 =   1.4296
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1929
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4680
# b =   5.7927
# gamma_k =   0.0817
# sigma =   0.2481
# LLs = -7848.7377
# AIC =  25.9362
# BIC =  17.9362
# No starting values entered: Using grid-search
# LL = -7825.6107
# ==========init params=========
# m0 =   1.4297
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1928
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.5254
# b =  49.9521
# gamma_k =   0.9529
# sigma =   0.2305
# LLs = -7863.4316
# AIC =  25.9400
# BIC =  17.9400
# No starting values entered: Using grid-search
# LL = -7826.9820
# ==========init params=========
# m0 =   1.4298
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1928
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4686
# b =   5.7676
# gamma_k =   0.0809
# sigma =   0.2483
# LLs = -7850.9974
# AIC =  25.9368
# BIC =  17.9368
# No starting values entered: Using grid-search
# LL = -7827.6594
# ==========init params=========
# m0 =   1.4296
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1927
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4686
# b =   5.7720
# gamma_k =   0.0809
# sigma =   0.2484
# LLs = -7851.7217
# AIC =  25.9370
# BIC =  17.9370
# No starting values entered: Using grid-search
# LL = -7829.4418
# ==========init params=========
# m0 =   1.4298
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1926
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4694
# b =   5.8107
# gamma_k =   0.0813
# sigma =   0.2488
# LLs = -7853.5002
# AIC =  25.9374
# BIC =  17.9374
# No starting values entered: Using grid-search
# LL = -7830.5379
# ==========init params=========
# m0 =   1.4295
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1925
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4704
# b =   6.0253
# gamma_k =   0.0852
# sigma =   0.2499
# LLs = -7854.2350
# AIC =  25.9376
# BIC =  17.9376
# No starting values entered: Using grid-search
# LL = -7830.8219
# ==========init params=========
# m0 =   1.4292
# b =   1.5000
# gamma_k =   0.1000
# sigma =   0.1925
#
#
#  ==========fitted results==========
# optimization method = slsqp
# m0 =   1.4696
# b =   5.9005
# gamma_k =   0.0828
# sigma =   0.2495
# LLs = -7854.7534
# AIC =  25.9377
# BIC =  17.9377

# %%
a = output
a["GVZ"] = xls_data["GVZ"]
a
# Out:
#            RV        m0          b   gamma_k     sigma    GVZ
# 0   11.687813  1.466268   5.764339  0.082307  0.246686  11.70
# 1   11.695531  1.466718   5.728050  0.081528  0.246767  12.99
# 2   11.738624  1.467818   5.880420  0.084104  0.247221  11.67
# 3   11.716048  1.467886   5.802658  0.082770  0.246984  12.28
# 4   11.784609  1.469714   5.991995  0.085954  0.247705  11.38
# 5   11.770267  1.468194   5.899889  0.084298  0.247554  11.39
# 6   11.811517  1.468556   6.069747  0.087525  0.247988  11.79
# 7   11.782923  1.467834   5.914861  0.084559  0.247688  11.02
# 8   11.809262  1.468204   5.997755  0.086020  0.247964  10.64
# 9   11.805972  1.468048   5.930450  0.084601  0.247930  10.72
# 10  11.806344  1.468039   5.887214  0.083659  0.247934  10.58
# 11  11.815212  1.468400   5.872800  0.083242  0.248027  10.75
# 12  11.814286  1.468256   5.829251  0.082380  0.248017  10.84
# 13  11.818054  1.468019   5.792729  0.081663  0.248056  11.18
# 14  10.205748  1.525380  49.952097  0.952917  0.230515  10.62
# 15  11.838105  1.468579   5.767566  0.080934  0.248267  11.02
# 16  11.853212  1.468616   5.772030  0.080907  0.248425  11.75
# 17  11.893520  1.469401   5.810697  0.081332  0.248847  11.61
# 18  11.992756  1.470378   6.025277  0.085231  0.249883  11.53
# 19  11.957893  1.469625   5.900540  0.082791  0.249520  11.68

# %% [markdown]
# ## plot

# %%
 msm_plot(xls_data["GVZ"], output, m)

# %% [markdown]
# ## Regression

# %%
datainreg = xls_data["GVZ"][::-1]
data_lastm = datainreg
data_lastm = data_lastm.iloc[-m:]

linreg(df(output['RV']), df(data_lastm))
# Out:
# Slope :  0.119141530313
# Intercept :  9.95948356095
# (0.11914153031294192, 9.9594835609536787)

# %% [markdown]
# ## XLSX

# %%
from datetime import date
text = 'MSM_fitparam'
namew=text + "_kbar" + str(kbar)+ "_RV" + str(22) +'_m' +str(m)+".xlsx"
writer = pd.ExcelWriter("".join((date.today().strftime('%y%m%d'),namew)))
print(writer.path)
output.to_excel(writer, 'Sheet2')
writer.save()
# Out:
# 180210MSM_fitparam_kbar3_RV22_m20.xlsx

# %% [markdown]
# ### load

# %%
xls_file = pd.ExcelFile('180209RV22m10.xlsx')
output = xls_file.parse('Sheet2')

# %% [markdown]
# # Average params

# %%
output2 = msm_averageparams(output, kbar, m, data, RV, LB , UB)

# %%
output2
# Out:
#            RV        m0          b   gamma_k     sigma
# 0   10.691455  1.502392  39.116365  0.930174  0.235937
# 1   10.691455  1.502392  39.116365  0.930174  0.235937
# 2   10.691455  1.502392  39.116365  0.930174  0.235937
# 3   10.691455  1.502392  39.116365  0.930174  0.235937
# 4   10.691455  1.502392  39.116365  0.930174  0.235937
# 5   10.691455  1.502392  39.116365  0.930174  0.235937
# 6   10.691455  1.502392  39.116365  0.930174  0.235937
# 7   10.691455  1.502392  39.116365  0.930174  0.235937
# 8   10.691455  1.502392  39.116365  0.930174  0.235937
# 9   10.691455  1.502392  39.116365  0.930174  0.235937
# 10  10.691455  1.502392  39.116365  0.930174  0.235937
# 11  10.691455  1.502392  39.116365  0.930174  0.235937
# 12  10.691455  1.502392  39.116365  0.930174  0.235937
# 13  10.691455  1.502392  39.116365  0.930174  0.235937
# 14  10.691455  1.502392  39.116365  0.930174  0.235937
# 15  10.691455  1.502392  39.116365  0.930174  0.235937
# 16  10.691455  1.502392  39.116365  0.930174  0.235937
# 17  10.691455  1.502392  39.116365  0.930174  0.235937
# 18  10.691455  1.502392  39.116365  0.930174  0.235937
# 19  10.691455  1.502392  39.116365  0.930174  0.235937

# %% [markdown]
# ## plot

# %%
 msm_plot(xls_data["GVZ"], output2, m)

# %% [markdown]
# ## Regression

# %%
datainreg = xls_data["GVZ"][::-1]
data_lastm = datainreg
data_lastm = data_lastm.iloc[-m:]

linreg(df(output2['RV']), df(data_lastm))
# Out:
# Slope :  9.03534675241e+13
# Intercept :  -9.66010049604e+14
# (90353467524120.281, -966010049603983.75)

# %%
data_lastm
# Out:
# 19    11.68
# 18    11.53
# 17    11.61
# 16    11.75
# 15    11.02
# 14    10.62
# 13    11.18
# 12    10.84
# 11    10.75
# 10    10.58
# 9     10.72
# 8     10.64
# 7     11.02
# 6     11.79
# 5     11.39
# 4     11.38
# 3     12.28
# 2     11.67
# 1     12.99
# 0     11.70
# Name: GVZ, dtype: float64
